# %% [markdown]
# ### Testing Prophet on mobile timeseries data

# %%
# import Prophet
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from fbprophet import Prophet
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('../data/new_data_backfill_forwfill.csv',index_col = 0)

# %%
agg_by_cell = df.groupby(by = df['cell_num'])
count = 0
for i,k in agg_by_cell: 
    print(i, k)
    count += 1
    if count > 1: break
# Out:
# 486-1252                date  cell_num  nr_people  hours  minutes
# 0        2017-04-16  486-1252       36.0    0.0      0.0
# 221      2017-04-16  486-1252       36.0    0.0     15.0
# 442      2017-04-16  486-1252       34.0    0.0     30.0
# 663      2017-04-16  486-1252       33.0    0.0     45.0
# 884      2017-04-16  486-1252       32.0    1.0      0.0
# ...             ...       ...        ...    ...      ...
# 2608463  2017-08-16  486-1252       41.0   22.0     45.0
# 2608684  2017-08-16  486-1252       40.0   23.0      0.0
# 2608905  2017-08-16  486-1252       39.0   23.0     15.0
# 2609126  2017-08-16  486-1252       40.0   23.0     30.0
# 2609347  2017-08-16  486-1252       40.0   23.0     45.0
#
# [11808 rows x 5 columns]
# 486-1253                date  cell_num  nr_people  hours  minutes
# 1        2017-04-16  486-1253       39.0    0.0      0.0
# 222      2017-04-16  486-1253       38.0    0.0     15.0
# 443      2017-04-16  486-1253       36.0    0.0     30.0
# 664      2017-04-16  486-1253       35.0    0.0     45.0
# 885      2017-04-16  486-1253       34.0    1.0      0.0
# ...             ...       ...        ...    ...      ...
# 2608464  2017-08-16  486-1253       46.0   22.0     45.0
# 2608685  2017-08-16  486-1253       45.0   23.0      0.0
# 2608906  2017-08-16  486-1253       45.0   23.0     15.0
# 2609127  2017-08-16  486-1253       45.0   23.0     30.0
# 2609348  2017-08-16  486-1253       45.0   23.0     45.0
#
# [11808 rows x 5 columns]

# %%
celldata = agg_by_cell.get_group('486-1264')
celldata.head()
# Out:
#            date  cell_num  nr_people  hours  minutes
# 12   2017-04-16  486-1264      373.0    0.0      0.0
# 233  2017-04-16  486-1264      368.0    0.0     15.0
# 454  2017-04-16  486-1264      363.0    0.0     30.0
# 675  2017-04-16  486-1264      351.0    0.0     45.0
# 896  2017-04-16  486-1264      343.0    1.0      0.0

# %%
# Prophet needs data in the following format  YYYY-MM-DD HH:MM:SS

celldata.shape
# Out:
# (11808, 5)

# %%
dates4prophet = []
cell_values = []
count = 0
for index, row in celldata.iterrows():
    
    date = row['date']
    h = str(row['hours'])
   
    h = h.split('.')
    
    if len(h[0])<2:
        h = h[1]+h[0]
    else: 
        h = h[0]
   
    minutes = str(row['minutes'])
    m = ''
    minutes = minutes.split('.')
    if len(minutes[0])<2: 
        m = minutes[0] +'0'
    else: 
        m = minutes[0]
    #print(date, h, m)
    data_f = date+' '+h+':'+m+':'+'00'
    #print(data_f)
    cell_values.append(row['nr_people'])
    dates4prophet.append(data_f)

# %%
di = {'ds': dates4prophet, 'y':cell_values}

# %%
data4prophet = pd.DataFrame(di)
data4prophet.shape
#print(data4prophet)
#train, test = data4prophet[:10000], data4prophet[10000:]
# Out:
# (11808, 2)

# %%
# fit the model
m = Prophet(changepoint_prior_scale=0.01).fit(data4prophet)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
# make predictions
# 28 / 4 = 952 sono il numero di ore in avanti che Prophet deve predire
future = m.make_future_dataframe(periods=0, freq='H')

# %%
future.tail()
# Out:
#                        ds
# 11803 2017-08-16 22:45:00
# 11804 2017-08-16 23:00:00
# 11805 2017-08-16 23:15:00
# 11806 2017-08-16 23:30:00
# 11807 2017-08-16 23:45:00

# %%
# make forcast and visualize plot
fcast = m.predict(future)

# %%
len(fcast)
# Out:
# 11808

# %%
figsize=(22, 10)
xlabel='ds'
ylabel='y'
fig = plt.figure(facecolor='w', figsize=figsize)

ax = fig.add_subplot(111)

fcast_t = fcast['ds'].dt.to_pydatetime()
ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.')
ax.plot(fcast_t, fcast['yhat'], ls='-', c='#0072B2')
plt.show()

# %%
fcast[['ds', 'trend', 'yhat', 'yhat_upper', 'yhat_lower']].head(10)
# Out:
#                    ds       trend        yhat  yhat_upper  yhat_lower
# 0 2017-04-16 00:00:00  410.463684  386.071126  433.033391  337.039616
# 1 2017-04-16 00:15:00  410.490856  377.877851  424.788340  332.237700
# 2 2017-04-16 00:30:00  410.518027  368.999544  412.826967  325.511861
# 3 2017-04-16 00:45:00  410.545198  359.490450  403.642443  313.517463
# 4 2017-04-16 01:00:00  410.572370  349.447378  396.384124  303.526223
# 5 2017-04-16 01:15:00  410.599541  339.003341  386.719127  293.448473
# 6 2017-04-16 01:30:00  410.626713  328.319124  373.048455  284.266850
# 7 2017-04-16 01:45:00  410.653884  317.573425  364.663857  271.932418
# 8 2017-04-16 02:00:00  410.681055  306.952273  350.056317  259.901447
# 9 2017-04-16 02:15:00  410.708227  296.638470  338.801903  251.291471

# %%
print(len(fcast))
# Out:
# 11808

# %%
yhat = fcast[11780:]
data4prophet_y = data4prophet[11780:]
y = data4prophet_y['y'].values
yhat = np.rint(yhat['yhat'].values)
print(len(yhat))
print(len(y))
# Out:
# 28
# 28

# %%
print(y[0:10])
print(yhat[0:10])
# Out:
# [481. 481. 488. 492. 490. 478. 470. 470. 477. 479.]
# [526. 529. 531. 532. 530. 527. 522. 515. 507. 499.]

# %%
difference = abs(y - yhat)

# %%
# show boxplot
plt.figure(figsize = (14,1))
plt.boxplot(difference, vert= False);
print('Mean Absolute Error = ', np.mean(difference))
# Out:
# Mean Absolute Error =  37.107142857142854

# %% [markdown]
# ### Calcolo per tutte le celle

# %%
counter = 0
dict2data = {}
error_list = []
for i,k in agg_by_cell: 
    
    cell = i
    print(counter)
    counter +=1
    dates4prophet = []
    cell_values = []
    
    for index, row in k.iterrows():
    
        date = row['date']
        h = str(row['hours'])
   
        h = h.split('.')
    
        if len(h[0])<2:
            h = h[1]+h[0]
        else: 
            h = h[0]
   
        minutes = str(row['minutes'])
        m = ''
        minutes = minutes.split('.')
        if len(minutes[0])<2: 
            m = minutes[0] +'0'
        else: 
            m = minutes[0]
        #print(date, h, m)
        data_f = date+' '+h+':'+m+':'+'00'
        #print(data_f)
        cell_values.append(row['nr_people'])
        dates4prophet.append(data_f)    
    
    # build data for prophet
    dict_i = {'ds': dates4prophet, 'y':cell_values}
    data4prophet = pd.DataFrame(dict_i)
    

    # fit the model
    m = Prophet(changepoint_prior_scale=0.01).fit(data4prophet)
    
    # make predictions
    future = m.make_future_dataframe(periods=0, freq='H')
    
    # make forcast.. 
    fcast = m.predict(future)
    
    # visualize cell values
    plt.figure(figsize = (14,1))
    plt.title('Value distrib. for cell '+str(i)) 
    plt.boxplot(cell_values, vert= False);
    plt.show()
    
    # compute difference between predicted and real value 
    
    #yhat = np.rint(fcst['yhat'].values)
    #max_element_in_cell = max(cell_values)
    difference = np.array([])
    
    steps_forcasting = 28
    divide = len(data4prophet) - steps_forcasting
    print(divide)
    yhat = fcast[divide:]
    data4prophet_y = data4prophet[divide:]
    y = data4prophet_y['y'].values
    yhat = np.rint(yhat['yhat'].values)
    difference = abs(y - yhat)
    
    # ..and visualize plot
    plt.figure(figsize = (14,1))
    plt.title('Error distrib. for cell '+str(i)) 
    plt.boxplot(difference, vert= False);
    print('Mean Absolute Error = ', np.mean(difference))
    plt.show()
    
    # collect data 2 dictionary
    minimum = np.amin(difference)   
    per75 = np.percentile(difference, 75)
    per50 = np.percentile(difference, 50)
    per25 = np.percentile(difference, 25)
    maximum = np.amax(difference)
    l5i = [minimum, per25, per50, per75, maximum]
    dict2data[cell] = l5i
    error_i = np.mean(difference)
    error_list.append(error_i)
# Out:
# 0
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.428571428571429
# 1
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.285714285714286
# 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.857142857142857
# 3
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.0
# 4
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.714285714285714
# 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  4.857142857142857
# 6
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5357142857142856
# 7
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.4642857142857144
# 8
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5357142857142856
# 9
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5357142857142856
# 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5357142857142856
# 11
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  38.285714285714285
# 12
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  37.107142857142854
# 13
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  10.0
# 14
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  2.7142857142857144
# 15
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  1.5
# 16
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  1.1428571428571428
# 17
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  7.357142857142857
# 18
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.214285714285714
# 19
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.821428571428571
# 20
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.0
# 21
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.857142857142857
# 22
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  7.25
# 23
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  7.5
# 24
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  4.75
# 25
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5357142857142856
# 26
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.5
# 27
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.892857142857143
# 28
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  42.5
# 29
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  30.107142857142858
# 30
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  11.071428571428571
# 31
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.035714285714286
# 32
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  1.6071428571428572
# 33
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.142857142857143
# 34
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  33.857142857142854
# 35
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  30.357142857142858
# 36
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  12.0
# 37
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.857142857142857
# 38
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.714285714285714
# 39
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.821428571428571
# 40
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  12.75
# 41
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.071428571428571
# 42
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  7.714285714285714
# 43
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.892857142857143
# 44
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  4.071428571428571
# 45
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  27.214285714285715
# 46
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  28.964285714285715
# 47
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  28.571428571428573
# 48
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  16.642857142857142
# 49
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.9285714285714284
# 50
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.464285714285714
# 51
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  58.142857142857146
# 52
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  51.57142857142857
# 53
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  28.714285714285715
# 54
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  23.75
# 55
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.892857142857142
# 56
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.5
# 57
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  11.714285714285714
# 58
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  9.821428571428571
# 59
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.357142857142858
# 60
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.428571428571429
# 61
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  7.678571428571429
# 62
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  4.035714285714286
# 63
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.428571428571429
# 64
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.857142857142857
# 65
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.035714285714286
# 66
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  4.0
# 67
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.857142857142857
# 68
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  34.857142857142854
# 69
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  11.571428571428571
# 70
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  51.357142857142854
# 71
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  13.892857142857142
# 72
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  44.75
# 73
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  15.214285714285714
# 74
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  10.214285714285714
# 75
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.285714285714286
# 76
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.25
# 77
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.25
# 78
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.285714285714286
# 79
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  2.7142857142857144
# 80
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  0.6071428571428571
# 81
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  0.8214285714285714
# 82
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  2.357142857142857
# 83
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  2.5
# 84
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  5.892857142857143
# 85
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  8.607142857142858
# 86
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  6.821428571428571
# 87
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  14.035714285714286
# 88
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  29.035714285714285
# 89
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  18.928571428571427
# 90
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  21.5
# 91
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  87.82142857142857
# 92
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  199.0
# 93
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  51.142857142857146
# 94
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  3.0357142857142856
# 95
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  1.6428571428571428
# 96
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  1.1071428571428572
# 97
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  0.8571428571428571
# 98
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 11780
# Mean Absolute Error =  0