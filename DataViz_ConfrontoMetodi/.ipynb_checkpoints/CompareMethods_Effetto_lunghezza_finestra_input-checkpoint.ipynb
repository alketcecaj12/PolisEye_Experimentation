# %% [markdown]
# ### Efetto lunghezza della finestra di input sull'errore di previsione

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
colnames = ['min', 'Q1', 'mediana', 'Q3', 'max']

# cambiare i per corsi con i propri dati
in16_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_16_16.csv', names=colnames, header=None)

in24_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_24_16.csv', names=colnames, header=None)

in35_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_35_16.csv', names=colnames, header=None)

in54_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_54_16.csv', names=colnames, header=None)

in75_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_75_16.csv', names=colnames, header=None)

in96_16 = pd.read_csv('/Users/alket/Desktop/poliseye_timeseries/DeepLearningModels/univariate-multisteps/MLP_MultistepForcast_VariabilitàErrore_96_16.csv', names=colnames, header=None)

# %%
in16_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 5 columns):
# min        221 non-null object
# Q1         221 non-null float64
# mediana    221 non-null float64
# Q3         221 non-null float64
# max        221 non-null object
# dtypes: float64(3), object(2)
# memory usage: 8.8+ KB

# %%
max_in16_16= []
for i, row in in16_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-2]
    max_in16_16.append(float(max_i))
    
max_in24_16= []
for i, row in in24_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-1]
    max_in24_16.append(float(max_i))    
 
max_in35_16= []
for i, row in in35_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-1]
    max_in35_16.append(float(max_i))
    
max_in54_16= []
for i, row in in54_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-1]
    max_in54_16.append(float(max_i))
    
max_in75_16= []
for i, row in in75_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-1]
    max_in75_16.append(float(max_i)) 
    
max_in96_16= []
for i, row in in96_16.iterrows():
    max_i= row['max']
    max_i = max_i[0:-1]
    max_in96_16.append(float(max_i))

# %%
max_in16_16 = np.array(max_in16_16)
max_in24_16 = np.array(max_in24_16)
max_in35_16 = np.array(max_in35_16)
max_in54_16 = np.array(max_in54_16)
max_in75_16 = np.array(max_in75_16)
max_in96_16 = np.array(max_in75_16)

# %%
med_in16_16 = np.array(in16_16['mediana'].tolist())
med_in24_16 = np.array(in24_16['mediana'].tolist())
med_in35_16 = np.array(in35_16['mediana'].tolist())
med_in54_16 = np.array(in54_16['mediana'].tolist())
med_in75_16 = np.array(in75_16['mediana'].tolist())
med_in96_16 = np.array(in75_16['mediana'].tolist())

# %%
print(max_in16_16[1])
print(max_in24_16[1])
print(max_in35_16[1])
print(max_in54_16[1])
# Out:
# 29.9000015258789
# 26.0
# 30.299999237060547
# 19.299999237060547

# %% [markdown]
# ### Mediana

# %%
mediana_plot = [med_in16_16, med_in24_16, med_in35_16, med_in54_16, med_in75_16, med_in96_16]

# Create a figure instance
fig = plt.figure(1, figsize=(20, 7))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(mediana_plot, patch_artist=True)

ax.set_xticklabels(['16-16', '24-16', '35-16', '54-16', '75-16', '96-16'])


# Save the figure
fig.savefig('ConfrontoMetodi.jpeg', bbox_inches='tight')

# %% [markdown]
# ### Max

# %%
data_to_plot = [max_in16_16, max_in24_16, max_in35_16, max_in54_16, max_in75_16, max_in96_16]

# Create a figure instance
fig = plt.figure(1, figsize=(20, 7))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, patch_artist=True)

ax.set_xticklabels(['16-16', '24-16', '35-16', '54-16', '75-16', '96-16'])


# Save the figure
fig.savefig('ConfrontoMetodi.jpeg', bbox_inches='tight')

# %% [markdown]
# ### Q3

# %%
q3_in16_16 = np.array(in16_16['Q3'].tolist())
q3_in24_16 = np.array(in24_16['Q3'].tolist())
q3_in35_16 = np.array(in35_16['Q3'].tolist())
q3_in54_16 = np.array(in54_16['Q3'].tolist())
q3_in75_16 = np.array(in75_16['Q3'].tolist())
q3_in96_16 = np.array(in96_16['Q3'].tolist())

# %%
Q3_plot = [q3_in16_16, q3_in24_16, q3_in35_16, q3_in54_16, q3_in75_16, q3_in96_16]

# Create a figure instance
fig = plt.figure(1, figsize=(20, 7))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(Q3_plot, patch_artist=True)

ax.set_xticklabels(['16-16', '24-16', '35-16', '54-16', '75-16', '96_16'])


# Save the figure
fig.savefig('ConfrontoMetodi.jpeg', bbox_inches='tight')
