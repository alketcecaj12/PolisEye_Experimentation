# %% [markdown]
# ### Multistep_MLP_with_additive_Decomposition

# %%
from statsmodels.compat.pandas import deprecate_kwarg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
# additive decompose a contrived additive time series
from random import randrange
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv', index_col = 0, 
                   header=0, parse_dates=True)

# %%
agg_by_cell = data.groupby(by = ['cell_num'])
print(len(agg_by_cell), 'celle')
# Out:
# 221 celle

# %%
serie_dati = agg_by_cell.get_group('495-1266')
serie_dati
# Out:
#                date  cell_num  nr_people  hours  minutes
# 167      2017-04-16  495-1266      326.0    0.0      0.0
# 388      2017-04-16  495-1266      330.0    0.0     15.0
# 609      2017-04-16  495-1266      321.0    0.0     30.0
# 830      2017-04-16  495-1266      320.0    0.0     45.0
# 1051     2017-04-16  495-1266      318.0    1.0      0.0
# ...             ...       ...        ...    ...      ...
# 2608630  2017-08-16  495-1266      279.0   22.0     45.0
# 2608851  2017-08-16  495-1266      280.0   23.0      0.0
# 2609072  2017-08-16  495-1266      275.0   23.0     15.0
# 2609293  2017-08-16  495-1266      274.0   23.0     30.0
# 2609514  2017-08-16  495-1266      274.0   23.0     45.0
#
# [11808 rows x 5 columns]

# %%
counter = 0
dict2data = {}
error_list = []

print(counter)
counter +=1
dates4dec = []
cell_values = []

for index, row in serie_dati.iterrows():
    
        date = row['date']
        h = str(row['hours'])
   
        h = h.split('.')
    
        if len(h[0])<2:
            h = h[1]+h[0]
        else: 
            h = h[0]
   
        minutes = str(row['minutes'])
        m = ''
        minutes = minutes.split('.')
        if len(minutes[0])<2: 
            m = minutes[0] +'0'
        else: 
            m = minutes[0]
        #print(date, h, m)
        data_f = date+' '+h+':'+m+':'+'00'
        #print(data_f)
        cell_values.append(row['nr_people'])
        dates4dec.append(data_f)
# Out:
# 0

# %%
dict_i = {'ds': dates4dec, 'y':cell_values}
data4deco = pd.DataFrame(dict_i, index=None, columns=None)  
data4deco.head()
# Out:
#                     ds      y
# 0  2017-04-16 00:00:00  326.0
# 1  2017-04-16 00:15:00  330.0
# 2  2017-04-16 00:30:00  321.0
# 3  2017-04-16 00:45:00  320.0
# 4  2017-04-16 01:00:00  318.0

# %%
#data4deco.reset_index(inplace=True)
#data4deco['ds'] = pd.to_datetime(data4deco['ds'])
#data4deco = data4deco.set_index('ds')
#data4deco.head()

# %%
data4deco.info()
data4deco.y.interpolate(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11808 entries, 0 to 11807
# Data columns (total 2 columns):
# ds    11808 non-null object
# y     11808 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 184.6+ KB

# %%
decompfreq = 24 * 4
result = seasonal_decompose(data4deco['y'], freq=decompfreq, model='additive') 
with plt.rc_context():
     plt.rc("figure", figsize=(18,9))
     result.plot()
     plt.show()

# %%
type(result)
# Out:
# statsmodels.tsa.seasonal.DecomposeResult

# %%
result.seasonal
# Out:
# 0       -2.299992
# 1       -3.901341
# 2       -5.773267
# 3       -7.571679
# 4       -8.755508
#            ...
# 11803   -2.290685
# 11804   -1.753160
# 11805   -1.699283
# 11806   -2.284794
# 11807   -2.509691
# Name: y, Length: 11808, dtype: float64

# %%
### vedi esempio in documentazione e replica con i dati nello stesso formato.

# %%
result.observed
# Out:
# 0        326.0
# 1        330.0
# 2        321.0
# 3        320.0
# 4        318.0
#          ...
# 11803    279.0
# 11804    280.0
# 11805    275.0
# 11806    274.0
# 11807    274.0
# Name: y, Length: 11808, dtype: float64

# %%
result.resid
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 11803   NaN
# 11804   NaN
# 11805   NaN
# 11806   NaN
# 11807   NaN
# Name: y, Length: 11808, dtype: float64

# %%
result.resid.describe()
# Out:
# count    11712.000000
# mean        -0.025102
# std         11.490455
# min        -56.995346
# 25%         -7.360666
# 50%         -0.194159
# 75%          6.901490
# max         63.835426
# Name: y, dtype: float64

# %%
plt.figure(figsize = (18, 3))
plt.plot(result.resid)
plt.show()

# %%
result.trend
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 11803   NaN
# 11804   NaN
# 11805   NaN
# 11806   NaN
# 11807   NaN
# Name: y, Length: 11808, dtype: float64

# %%
plt.figure(figsize = (18, 3))
plt.plot(result.trend)
plt.show()
