# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import time
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error 
from math import sqrt
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import warnings 
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from keras import metrics

data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)

# preparazione dati per due celle
agg_by_cell = data.groupby(by = ['cell_num'])

# %%
num_data = []
## prepare dataset
for i, k in agg_by_cell:
    cell_i = agg_by_cell.get_group(i)
    # define input sequence
    series_i = cell_i['nr_people'].values
    series_i = series_i.reshape((len(series_i), 1))
    num_data.append(series_i)

# %%
print(num_data[:2][0])
print(len(num_data[:2]))
# Out:
# [[36.]
#  [36.]
#  [34.]
#  ...
#  [39.]
#  [40.]
#  [40.]]
# 2

# %%
final_data = hstack((num_data))
final_data.shape
# Out:
# (11808, 221)

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
  X, y = list(), list()
  for i in range(len(sequences)):
      # find the end of this pattern
      end_ix = i + n_steps_in
      out_end_ix = end_ix + n_steps_out
      # check if we are beyond the dataset
      if out_end_ix > len(sequences):
          break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
      X.append(seq_x)
      y.append(seq_y)
  return np.array(X), np.array(y)

# choose a number of time steps
n_steps_in, n_steps_out = 24, 8

# convert into input/output
X, y = split_sequences(final_data, n_steps_in, n_steps_out)

count = 0
for i in range(len(X)):
    count += 1
    print('inizia iterazione ', i)
    print(X[i], y[i])
    if count > 1: break
# flatten input
n_input = X.shape[1] * X.shape[2]
X = X.reshape((X.shape[0], n_input))

# flatten output
n_output = y.shape[1] * y.shape[2]
y = y.reshape((y.shape[0], n_output))
# Out:
# inizia iterazione  0
# [[ 36.  39.  41. ...  17. 104.  35.]
#  [ 36.  38.  40. ...  17. 106.  36.]
#  [ 34.  36.  38. ...  17. 107.  36.]
#  ...
#  [ 19.  19.  20. ...  17. 104.  35.]
#  [ 18.  19.  19. ...  17. 103.  34.]
#  [ 18.  18.  19. ...  17. 102.  34.]] [[ 18.  18.  19. ...  17. 102.  34.]
#  [ 19.  19.  20. ...  17. 103.  34.]
#  [ 21.  21.  22. ...  16. 102.  34.]
#  ...
#  [ 20.  21.  22. ...  16.  99.  33.]
#  [ 20.  21.  22. ...  17.  99.  33.]
#  [ 20.  21.  22. ...  17.  99.  33.]]
# inizia iterazione  1
# [[ 36.  38.  40. ...  17. 106.  36.]
#  [ 34.  36.  38. ...  17. 107.  36.]
#  [ 33.  35.  37. ...  17. 106.  35.]
#  ...
#  [ 18.  19.  19. ...  17. 103.  34.]
#  [ 18.  18.  19. ...  17. 102.  34.]
#  [ 18.  18.  19. ...  17. 102.  34.]] [[ 19.  19.  20. ...  17. 103.  34.]
#  [ 21.  21.  22. ...  16. 102.  34.]
#  [ 20.  21.  22. ...  17. 102.  34.]
#  ...
#  [ 20.  21.  22. ...  17.  99.  33.]
#  [ 20.  21.  22. ...  17.  99.  33.]
#  [ 19.  20.  20. ...  16.  96.  32.]]

# %%
#train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=1)
#train_X, val_X, train_y, val_y = train_test_split(train_X, train_y, test_size=0.3, random_state=1)
#print(len(train_X), len(train_y), len(test_X), len(test_y), len(val_X), len(val_y))
split_train_test = int(len(X)*0.75)
train_X, test_X = X[:split_train_test], X[split_train_test:]
train_y, test_y = y[:split_train_test], y[split_train_test:]
print(len(train_X), len(train_y), len(test_X), len(test_y))
# Out:
# 8832 8832 2945 2945

# %%
for i in range(220):
    print(final_data[i][0])
# Out:
# 36.0
# 36.0
# 34.0
# 33.0
# 32.0
# 33.0
# 32.0
# 30.0
# 30.0
# 29.0
# 29.0
# 27.0
# 27.0
# 25.0
# 24.0
# 23.0
# 22.0
# 21.0
# 20.0
# 20.0
# 19.0
# 19.0
# 18.0
# 18.0
# 18.0
# 19.0
# 21.0
# 20.0
# 20.0
# 20.0
# 20.0
# 20.0
# 19.0
# 19.0
# 19.0
# 21.0
# 21.0
# 23.0
# 23.0
# 27.0
# 27.0
# 28.0
# 28.0
# 26.0
# 25.0
# 25.0
# 25.0
# 25.0
# 26.0
# 27.0
# 27.0
# 27.0
# 29.0
# 29.0
# 30.0
# 30.0
# 30.0
# 30.0
# 29.0
# 30.0
# 31.0
# 33.0
# 33.0
# 34.0
# 35.0
# 35.0
# 38.0
# 38.0
# 41.0
# 43.0
# 43.0
# 44.0
# 42.0
# 42.0
# 41.0
# 40.0
# 40.0
# 40.0
# 40.0
# 40.0
# 41.0
# 41.0
# 41.0
# 40.0
# 40.0
# 40.0
# 40.0
# 37.0
# 36.0
# 35.0
# 35.0
# 35.0
# 33.0
# 32.0
# 32.0
# 32.0
# 33.0
# 33.0
# 30.0
# 29.0
# 28.0
# 28.0
# 27.0
# 27.0
# 26.0
# 26.0
# 26.0
# 25.0
# 25.0
# 25.0
# 25.0
# 25.0
# 23.0
# 23.0
# 23.0
# 23.0
# 23.0
# 19.0
# 19.0
# 19.0
# 19.0
# 19.0
# 19.0
# 19.0
# 20.0
# 20.0
# 20.0
# 19.0
# 19.0
# 19.0
# 18.0
# 18.0
# 18.0
# 18.0
# 18.0
# 24.0
# 27.0
# 29.0
# 29.0
# 31.0
# 33.0
# 33.0
# 33.0
# 34.0
# 34.0
# 35.0
# 37.0
# 39.0
# 41.0
# 41.0
# 41.0
# 41.0
# 41.0
# 41.0
# 41.0
# 40.0
# 42.0
# 42.0
# 43.0
# 44.0
# 46.0
# 47.0
# 48.0
# 50.0
# 52.0
# 53.0
# 52.0
# 51.0
# 51.0
# 50.0
# 49.0
# 49.0
# 52.0
# 52.0
# 52.0
# 52.0
# 52.0
# 51.0
# 50.0
# 49.0
# 47.0
# 47.0
# 47.0
# 45.0
# 44.0
# 44.0
# 44.0
# 39.0
# 38.0
# 38.0
# 38.0
# 38.0
# 38.0
# 37.0
# 35.0
# 35.0
# 35.0
# 31.0
# 31.0
# 28.0
# 27.0
# 27.0
# 26.0
# 26.0
# 26.0
# 26.0
# 26.0
# 23.0
# 23.0
# 22.0
# 22.0
# 21.0
# 21.0
# 20.0
# 20.0
# 20.0
# 20.0
# 22.0
# 22.0
# 25.0

# %%
len(train_X)
# Out:
# 8832

# %%
final_data.shape
# Out:
# (11808, 221)

# %%
# define model
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=n_input)) 
model.add(Dense(250, activation='relu', input_dim=n_input)) 
model.add(Dense(n_output))
model.compile(optimizer='adam', loss='mse',  metrics=[metrics.mae, 'accuracy'])

# fit model
model.fit(train_X, train_y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 276/276 - 4s - loss: 2870.2039 - mean_absolute_error: 24.9755 - accuracy: 0.0884
# Epoch 2/100
# 276/276 - 4s - loss: 482.8885 - mean_absolute_error: 12.0160 - accuracy: 0.3108
# Epoch 3/100
# 276/276 - 4s - loss: 401.8106 - mean_absolute_error: 10.9624 - accuracy: 0.4334
# Epoch 4/100
# 276/276 - 4s - loss: 367.7312 - mean_absolute_error: 10.4432 - accuracy: 0.4464
# Epoch 5/100
# 276/276 - 4s - loss: 332.0202 - mean_absolute_error: 10.0115 - accuracy: 0.4534
# Epoch 6/100
# 276/276 - 4s - loss: 315.6029 - mean_absolute_error: 9.7843 - accuracy: 0.4513
# Epoch 7/100
# 276/276 - 4s - loss: 313.6688 - mean_absolute_error: 9.7094 - accuracy: 0.4572
# Epoch 8/100
# 276/276 - 4s - loss: 291.8961 - mean_absolute_error: 9.4799 - accuracy: 0.4601
# Epoch 9/100
# 276/276 - 4s - loss: 276.2394 - mean_absolute_error: 9.1490 - accuracy: 0.4556
# Epoch 10/100
# 276/276 - 4s - loss: 257.3414 - mean_absolute_error: 8.7075 - accuracy: 0.4566
# Epoch 11/100
# 276/276 - 4s - loss: 257.1985 - mean_absolute_error: 8.8236 - accuracy: 0.4608
# Epoch 12/100
# 276/276 - 4s - loss: 265.7367 - mean_absolute_error: 8.9662 - accuracy: 0.4612
# Epoch 13/100
# 276/276 - 4s - loss: 239.1223 - mean_absolute_error: 8.2845 - accuracy: 0.4660
# Epoch 14/100
# 276/276 - 4s - loss: 226.7640 - mean_absolute_error: 8.1105 - accuracy: 0.4664
# Epoch 15/100
# 276/276 - 4s - loss: 242.9007 - mean_absolute_error: 8.6286 - accuracy: 0.4668
# Epoch 16/100
# 276/276 - 4s - loss: 230.2837 - mean_absolute_error: 8.2320 - accuracy: 0.4763
# Epoch 17/100
# 276/276 - 4s - loss: 230.4837 - mean_absolute_error: 8.2062 - accuracy: 0.4742
# Epoch 18/100
# 276/276 - 5s - loss: 229.5819 - mean_absolute_error: 8.2529 - accuracy: 0.4720
# Epoch 19/100
# 276/276 - 4s - loss: 218.6403 - mean_absolute_error: 8.0323 - accuracy: 0.4721
# Epoch 20/100
# 276/276 - 4s - loss: 205.7011 - mean_absolute_error: 7.6543 - accuracy: 0.4802
# Epoch 21/100
# 276/276 - 4s - loss: 220.5321 - mean_absolute_error: 8.0024 - accuracy: 0.4794
# Epoch 22/100
# 276/276 - 4s - loss: 204.7043 - mean_absolute_error: 7.6910 - accuracy: 0.4841
# Epoch 23/100
# 276/276 - 4s - loss: 205.0880 - mean_absolute_error: 7.6746 - accuracy: 0.4811
# Epoch 24/100
# 276/276 - 4s - loss: 201.1502 - mean_absolute_error: 7.6325 - accuracy: 0.4836
# Epoch 25/100
# 276/276 - 4s - loss: 210.4953 - mean_absolute_error: 7.8599 - accuracy: 0.4795
# Epoch 26/100
# 276/276 - 4s - loss: 202.7088 - mean_absolute_error: 7.6420 - accuracy: 0.4841
# Epoch 27/100
# 276/276 - 4s - loss: 199.9540 - mean_absolute_error: 7.5892 - accuracy: 0.4881
# Epoch 28/100
# 276/276 - 4s - loss: 192.7903 - mean_absolute_error: 7.4220 - accuracy: 0.4819
# Epoch 29/100
# 276/276 - 4s - loss: 199.6895 - mean_absolute_error: 7.6041 - accuracy: 0.4863
# Epoch 30/100
# 276/276 - 4s - loss: 207.8033 - mean_absolute_error: 7.7625 - accuracy: 0.4844
# Epoch 31/100
# 276/276 - 4s - loss: 187.5663 - mean_absolute_error: 7.2652 - accuracy: 0.4926
# Epoch 32/100
# 276/276 - 4s - loss: 181.2612 - mean_absolute_error: 7.1024 - accuracy: 0.4894
# Epoch 33/100
# 276/276 - 4s - loss: 197.2557 - mean_absolute_error: 7.5027 - accuracy: 0.4881
# Epoch 34/100
# 276/276 - 4s - loss: 182.4368 - mean_absolute_error: 7.1459 - accuracy: 0.4846
# Epoch 35/100
# 276/276 - 4s - loss: 178.4076 - mean_absolute_error: 6.9983 - accuracy: 0.4952
# Epoch 36/100
# 276/276 - 4s - loss: 192.2719 - mean_absolute_error: 7.3775 - accuracy: 0.4904
# Epoch 37/100
# 276/276 - 4s - loss: 180.9459 - mean_absolute_error: 7.0339 - accuracy: 0.4958
# Epoch 38/100
# 276/276 - 4s - loss: 182.7880 - mean_absolute_error: 7.0964 - accuracy: 0.4917
# Epoch 39/100
# 276/276 - 4s - loss: 190.6670 - mean_absolute_error: 7.3068 - accuracy: 0.4866
# Epoch 40/100
# 276/276 - 4s - loss: 188.8154 - mean_absolute_error: 7.2905 - accuracy: 0.4925
# Epoch 41/100
# 276/276 - 4s - loss: 177.0393 - mean_absolute_error: 6.9157 - accuracy: 0.4941
# Epoch 42/100
# 276/276 - 4s - loss: 182.1813 - mean_absolute_error: 7.0527 - accuracy: 0.4915
# Epoch 43/100
# 276/276 - 4s - loss: 172.1672 - mean_absolute_error: 6.8261 - accuracy: 0.4923
# Epoch 44/100
# 276/276 - 4s - loss: 167.5385 - mean_absolute_error: 6.6998 - accuracy: 0.5006
# Epoch 45/100
# 276/276 - 4s - loss: 175.3885 - mean_absolute_error: 6.9396 - accuracy: 0.4962
# Epoch 46/100
# 276/276 - 4s - loss: 176.7318 - mean_absolute_error: 6.9646 - accuracy: 0.4887
# Epoch 47/100
# 276/276 - 4s - loss: 171.4967 - mean_absolute_error: 6.8100 - accuracy: 0.4988
# Epoch 48/100
# 276/276 - 4s - loss: 169.2057 - mean_absolute_error: 6.7489 - accuracy: 0.5007
# Epoch 49/100
# 276/276 - 4s - loss: 159.3504 - mean_absolute_error: 6.5176 - accuracy: 0.5046
# Epoch 50/100
# 276/276 - 4s - loss: 174.5129 - mean_absolute_error: 6.8929 - accuracy: 0.4964
# Epoch 51/100
# 276/276 - 4s - loss: 173.9852 - mean_absolute_error: 6.8464 - accuracy: 0.4985
# Epoch 52/100
# 276/276 - 4s - loss: 160.0371 - mean_absolute_error: 6.5575 - accuracy: 0.5052
# Epoch 53/100
# 276/276 - 4s - loss: 166.5372 - mean_absolute_error: 6.7152 - accuracy: 0.5043
# Epoch 54/100
# 276/276 - 4s - loss: 164.6303 - mean_absolute_error: 6.6860 - accuracy: 0.5035
# Epoch 55/100
# 276/276 - 4s - loss: 165.3360 - mean_absolute_error: 6.7040 - accuracy: 0.5034
# Epoch 56/100
# 276/276 - 4s - loss: 158.6308 - mean_absolute_error: 6.5175 - accuracy: 0.5053
# Epoch 57/100
# 276/276 - 4s - loss: 169.1340 - mean_absolute_error: 6.7406 - accuracy: 0.4999
# Epoch 58/100
# 276/276 - 4s - loss: 163.1855 - mean_absolute_error: 6.6113 - accuracy: 0.5087
# Epoch 59/100
# 276/276 - 5s - loss: 158.5105 - mean_absolute_error: 6.5478 - accuracy: 0.5031
# Epoch 60/100
# 276/276 - 4s - loss: 154.7423 - mean_absolute_error: 6.4481 - accuracy: 0.5054
# Epoch 61/100
# 276/276 - 4s - loss: 160.5934 - mean_absolute_error: 6.6067 - accuracy: 0.5044
# Epoch 62/100
# 276/276 - 4s - loss: 161.1312 - mean_absolute_error: 6.5856 - accuracy: 0.5011
# Epoch 63/100
# 276/276 - 4s - loss: 155.4905 - mean_absolute_error: 6.4732 - accuracy: 0.5057
# Epoch 64/100
# 276/276 - 4s - loss: 160.4375 - mean_absolute_error: 6.5919 - accuracy: 0.5027
# Epoch 65/100
# 276/276 - 4s - loss: 162.5511 - mean_absolute_error: 6.6538 - accuracy: 0.5019
# Epoch 66/100
# 276/276 - 4s - loss: 154.4285 - mean_absolute_error: 6.4388 - accuracy: 0.5029
# Epoch 67/100
# 276/276 - 4s - loss: 156.8702 - mean_absolute_error: 6.4894 - accuracy: 0.5024
# Epoch 68/100
# 276/276 - 4s - loss: 159.4661 - mean_absolute_error: 6.5559 - accuracy: 0.5008
# Epoch 69/100
# 276/276 - 4s - loss: 155.9296 - mean_absolute_error: 6.4775 - accuracy: 0.5060
# Epoch 70/100
# 276/276 - 4s - loss: 156.5925 - mean_absolute_error: 6.5324 - accuracy: 0.5002
# Epoch 71/100
# 276/276 - 4s - loss: 153.8794 - mean_absolute_error: 6.4478 - accuracy: 0.5117
# Epoch 72/100
# 276/276 - 4s - loss: 153.0694 - mean_absolute_error: 6.4064 - accuracy: 0.5083
# Epoch 73/100
# 276/276 - 4s - loss: 154.9072 - mean_absolute_error: 6.4796 - accuracy: 0.5063
# Epoch 74/100
# 276/276 - 4s - loss: 147.0229 - mean_absolute_error: 6.2750 - accuracy: 0.5127
# Epoch 75/100
# 276/276 - 4s - loss: 148.1451 - mean_absolute_error: 6.2963 - accuracy: 0.5074
# Epoch 76/100
# 276/276 - 4s - loss: 153.2150 - mean_absolute_error: 6.4909 - accuracy: 0.5054
# Epoch 77/100
# 276/276 - 4s - loss: 147.4386 - mean_absolute_error: 6.3037 - accuracy: 0.5103
# Epoch 78/100
# 276/276 - 4s - loss: 147.7446 - mean_absolute_error: 6.3184 - accuracy: 0.5135
# Epoch 79/100
# 276/276 - 4s - loss: 151.6567 - mean_absolute_error: 6.3931 - accuracy: 0.5103
# Epoch 80/100
# 276/276 - 4s - loss: 146.8845 - mean_absolute_error: 6.2729 - accuracy: 0.5137
# Epoch 81/100
# 276/276 - 4s - loss: 146.2497 - mean_absolute_error: 6.2414 - accuracy: 0.5108
# Epoch 82/100
# 276/276 - 4s - loss: 150.3006 - mean_absolute_error: 6.3646 - accuracy: 0.5126
# Epoch 83/100
# 276/276 - 4s - loss: 154.5361 - mean_absolute_error: 6.4838 - accuracy: 0.5137
# Epoch 84/100
# 276/276 - 4s - loss: 153.8940 - mean_absolute_error: 6.4497 - accuracy: 0.5053
# Epoch 85/100
# 276/276 - 4s - loss: 150.6178 - mean_absolute_error: 6.3544 - accuracy: 0.5129
# Epoch 86/100
# 276/276 - 4s - loss: 150.0643 - mean_absolute_error: 6.3884 - accuracy: 0.5065
# Epoch 87/100
# 276/276 - 4s - loss: 146.0300 - mean_absolute_error: 6.2625 - accuracy: 0.5157
# Epoch 88/100
# 276/276 - 4s - loss: 148.1111 - mean_absolute_error: 6.3150 - accuracy: 0.5109
# Epoch 89/100
# 276/276 - 4s - loss: 145.2519 - mean_absolute_error: 6.2638 - accuracy: 0.5168
# Epoch 90/100
# 276/276 - 4s - loss: 147.7261 - mean_absolute_error: 6.3141 - accuracy: 0.5100
# Epoch 91/100
# 276/276 - 4s - loss: 144.8226 - mean_absolute_error: 6.2405 - accuracy: 0.5117
# Epoch 92/100
# 276/276 - 4s - loss: 144.8884 - mean_absolute_error: 6.2544 - accuracy: 0.5143
# Epoch 93/100
# 276/276 - 4s - loss: 145.3913 - mean_absolute_error: 6.2572 - accuracy: 0.5147
# Epoch 94/100
# 276/276 - 4s - loss: 142.7856 - mean_absolute_error: 6.1889 - accuracy: 0.5129
# Epoch 95/100
# 276/276 - 4s - loss: 143.6174 - mean_absolute_error: 6.2118 - accuracy: 0.5178
# Epoch 96/100
# 276/276 - 4s - loss: 150.0759 - mean_absolute_error: 6.4032 - accuracy: 0.5085
# Epoch 97/100
# 276/276 - 4s - loss: 147.7955 - mean_absolute_error: 6.3347 - accuracy: 0.5131
# Epoch 98/100
# 276/276 - 3s - loss: 144.3506 - mean_absolute_error: 6.2521 - accuracy: 0.5153
# Epoch 99/100
# 276/276 - 4s - loss: 152.0328 - mean_absolute_error: 6.4591 - accuracy: 0.5157
# Epoch 100/100
# 276/276 - 4s - loss: 143.4627 - mean_absolute_error: 6.2170 - accuracy: 0.5142

# %%
predicted = np.array([])
for i in range(len(test_X)):
    x_input = test_X[i].reshape((1, n_input))
    yhat = model.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted = np.append(predicted, yhat[0])

print(len(test_y))
var4diff2 = len(test_y)
print('shape ',test_y.shape )
exp_y = test_y.reshape((test_y.shape[0] * test_y.shape[1]))    
expected = exp_y    
print(len(expected))
print(len(predicted))
# Out:
# 2945
# shape  (2945, 1768)
# 5206760
# 5206760

# %%
difference = abs(predicted - expected)
print('Mean Absolute Error = ', np.mean(difference))
plt.figure(figsize = (14,2))
plt.boxplot(difference, vert = False)
plt.show()
# Out:
# Mean Absolute Error =  9.333117885790399

# %%
shape_i = final_data.shape[1] * n_steps_out 
print(shape_i)
# Out:
# 1768

# %%
difference2 = difference.reshape( var4diff2, shape_i)
print(difference2.shape)
# Out:
# (2945, 1768)

# %%
plt.figure(figsize = (20,140))
plt.boxplot(difference2, vert = False)
plt.show()
