# %% [markdown]
# ### Metto insieme i features creati ('is_holiday') con i lag per vedere se posso migliorare la previsione

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import time
from sklearn.preprocessing import MinMaxScaler

from math import sqrt
from keras.models import Sequential
from keras.layers import Dense
from time import time
import os
from IPython.utils import traitlets as _traitlets
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import TensorBoard
from keras.layers import LSTM
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import warnings 
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras import metrics

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# /Users/alket/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   app.launch_new_instance()

# %%
data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)

agg_by_cell = data.groupby(by = ['cell_num'])
series = agg_by_cell.get_group('488-1264')
series.head()
# Out:
#            date  cell_num  nr_people  hours  minutes
# 46   2017-04-16  488-1264      394.0    0.0      0.0
# 267  2017-04-16  488-1264      396.0    0.0     15.0
# 488  2017-04-16  488-1264      387.0    0.0     30.0
# 709  2017-04-16  488-1264      375.0    0.0     45.0
# 930  2017-04-16  488-1264      365.0    1.0      0.0

# %% [markdown]
# ### Creazione di features

# %% [markdown]
# #### Crea feature 'is_buisness_day' che vale 1 se è un giorno lavorativo, 0 altrimenti

# %%
# crea un campo 'is_business_day' con valore binario
def find_business_days(data):
    business_day = []
    for i in data['date']:
        #print(i)
        s = i.split('-')
        year = int(s[0])
       # print(year, '----------------_>>>>><')
        month = int(s[1])
        day = int(s[2])
        ##print(day, ' ', month, ' ', year)
    
        dayofweek = datetime.date(year, month, day).strftime("%A")
        if ((dayofweek == 'Saturday') | (dayofweek == 'Sunday')): 
            business_day.append(0)
        else: 
            business_day.append(1)
     
    return business_day

bd = find_business_days(series)
series['is_business_day']= bd

# %%
series.head()
# Out:
#            date  cell_num  nr_people  hours  minutes  is_business_day
# 46   2017-04-16  488-1264      394.0    0.0      0.0                0
# 267  2017-04-16  488-1264      396.0    0.0     15.0                0
# 488  2017-04-16  488-1264      387.0    0.0     30.0                0
# 709  2017-04-16  488-1264      375.0    0.0     45.0                0
# 930  2017-04-16  488-1264      365.0    1.0      0.0                0

# %% [markdown]
# #### Crea feature 'is_April', 'is_May' ecc.. che vale 1 se si tratta del mese in questione, vale 0 altrimenti

# %%
# crea un campo 'is_Month' con valore binario
def find_month(data):
    april = []
    may = []
    june = []
    july = []
    august = []
    
    for i in data['date']:
        #print(i)
        s = i.split('-')
        year = int(s[0])
       # print(year, '----------------_>>>>><')
        month = int(s[1])
        #print(month)
        if month == 4:
            april.append(1)
            may.append(0)
            june.append(0)
            july.append(0)
            august.append(0)
        if month == 5:
            april.append(0)
            may.append(1)
            june.append(0)
            july.append(0)
            august.append(0)
        if month == 6:
            april.append(0)
            may.append(0)
            june.append(1)
            july.append(0)
            august.append(0)
        if month == 7:
            april.append(0)
            may.append(0)
            june.append(0)
            july.append(1)
            august.append(0) 
        if month == 8:
            april.append(0)
            may.append(0)
            june.append(0)
            july.append(0)
            august.append(1)     
     
    return april, may, june, july, august

april, may, june, july, august = find_month(series)
series['is_April']= april
series['is_May']= may
series['is_June']= june
series['is_July']= july
series['is_August']= august

# %%
series.head()
# Out:
#            date  cell_num  nr_people  hours  minutes  is_business_day  \
# 46   2017-04-16  488-1264      394.0    0.0      0.0                0
# 267  2017-04-16  488-1264      396.0    0.0     15.0                0
# 488  2017-04-16  488-1264      387.0    0.0     30.0                0
# 709  2017-04-16  488-1264      375.0    0.0     45.0                0
# 930  2017-04-16  488-1264      365.0    1.0      0.0                0
#
#      is_April  is_May  is_June  is_July  is_August
# 46          1       0        0        0          0
# 267         1       0        0        0          0
# 488         1       0        0        0          0
# 709         1       0        0        0          0
# 930         1       0        0        0          0

# %% [markdown]
# #### Crea feature is_Day es. 'is_Monday' che vale 1 se si tratta del giorno in questione, vale 0 altrimenti

# %%
# crea un campo 'is_Day' con valore binario
def find_month(data):
    monday = []
    tuesday = []
    wednesday = []
    thursday = []
    friday = []
    
    for i in data['date']:
        s = i.split('-')
        year = int(s[0])
        month = int(s[1])
        day = int(s[2])
        
        dayofweek = datetime.date(year, month, day).strftime("%A")
        if (dayofweek == 'Monday'): 
            monday.append(1)
            tuesday.append(0)
            wednesday.append(0)
            thursday.append(0)
            friday.append(0)
        if (dayofweek == 'Tuesday'):
            monday.append(0)
            tuesday.append(1)
            wednesday.append(0)
            thursday.append(0)
            friday.append(0)
        if (dayofweek == 'Wednesday'):
            monday.append(0)
            tuesday.append(0)
            wednesday.append(1)
            thursday.append(0)
            friday.append(0)
        if (dayofweek == 'Thursday'):
            monday.append(0)
            tuesday.append(0)
            wednesday.append(0)
            thursday.append(1)
            friday.append(0) 
        if (dayofweek == 'Friday'):
            monday.append(0)
            tuesday.append(0)
            wednesday.append(0)
            thursday.append(0)
            friday.append(1)     
        if (dayofweek == 'Saturday'):
            monday.append(0)
            tuesday.append(0)
            wednesday.append(0)
            thursday.append(0)
            friday.append(0)          
        if (dayofweek == 'Sunday'):
            monday.append(0)
            tuesday.append(0)
            wednesday.append(0)
            thursday.append(0)
            friday.append(0) 
              
    return monday, tuesday, wednesday, thursday, friday

monday, tuesday, wednesday, thursday, friday = find_month(series)
print(len(monday))
print(len(tuesday))
print(len(friday))
series['is_Monday']= monday
series['is_Tuesday']= tuesday
series['is_Wednesday']= wednesday
series['is_Thursday']= thursday
series['is_Friday']= friday
# Out:
# 11808
# 11808
# 11808

# %%
series.head(4)
# Out:
#            date  cell_num  nr_people  hours  minutes  is_business_day  \
# 46   2017-04-16  488-1264      394.0    0.0      0.0                0
# 267  2017-04-16  488-1264      396.0    0.0     15.0                0
# 488  2017-04-16  488-1264      387.0    0.0     30.0                0
# 709  2017-04-16  488-1264      375.0    0.0     45.0                0
#
#      is_April  is_May  is_June  is_July  is_August  is_Monday  is_Tuesday  \
# 46          1       0        0        0          0          0           0
# 267         1       0        0        0          0          0           0
# 488         1       0        0        0          0          0           0
# 709         1       0        0        0          0          0           0
#
#      is_Wednesday  is_Thursday  is_Friday
# 46              0            0          0
# 267             0            0          0
# 488             0            0          0
# 709             0            0          0

# %% [markdown]
# #### Crea feature 'is_holiday' che vale 1 se è un giorno festivo (Pasqua, Liberazione ecc..), 0 altrimenti

# %%
# crea campo 'is_public_holiday'
# Pasqua: domenica 16 aprile 2017
# Lunedì dell'Angelo: lunedì 17 aprile 2017
# Festa della Liberazione: martedì 25 aprile 2017
# Festa del Lavoro: lunedì 1 maggio 2017
# Festa della Repubblica: venerdi 2 giugno 2017
# Ferragosto: martedì 15 agosto 2017
def find_holiday_days(data):
    holiday = []
    for i in data['date']:
        #print(i)
        if ((i == '2017-04-16') | (i == '2017-04-17') | (i == '2017-04-25') | 
            (i == '2017-05-01') | (i == '2017-06-02') | (i == '2017-08-15')): 
            holiday.append(1)
        else: 
            holiday.append(0)
     
    return holiday

hd = find_holiday_days(series)
series['is_holiday']= hd  
series.head(3)
# Out:
#            date  cell_num  nr_people  hours  minutes  is_business_day  \
# 46   2017-04-16  488-1264      394.0    0.0      0.0                0
# 267  2017-04-16  488-1264      396.0    0.0     15.0                0
# 488  2017-04-16  488-1264      387.0    0.0     30.0                0
#
#      is_April  is_May  is_June  is_July  is_August  is_Monday  is_Tuesday  \
# 46          1       0        0        0          0          0           0
# 267         1       0        0        0          0          0           0
# 488         1       0        0        0          0          0           0
#
#      is_Wednesday  is_Thursday  is_Friday  is_holiday
# 46              0            0          0           1
# 267             0            0          0           1
# 488             0            0          0           1

# %% [markdown]
# #### Crea feature 'is_business_hour' che vale 1 se 9.00 <= osservazione <= 21.00 , 0 altrimenti

# %%
def find_business_hours(data):
    business_h = []
    for i in data['hours']:
        if i > 8 and i < 21 :
            business_h.append(1)
        
        else:
            business_h.append(0)
    return business_h  

business_h = find_business_hours(series)        
series['is_business_hour'] = business_h
series.tail(3)
# Out:
#                date  cell_num  nr_people  hours  minutes  is_business_day  \
# 2608951  2017-08-16  488-1264      362.0   23.0     15.0                1
# 2609172  2017-08-16  488-1264      356.0   23.0     30.0                1
# 2609393  2017-08-16  488-1264      356.0   23.0     45.0                1
#
#          is_April  is_May  is_June  is_July  is_August  is_Monday  is_Tuesday  \
# 2608951         0       0        0        0          1          0           0
# 2609172         0       0        0        0          1          0           0
# 2609393         0       0        0        0          1          0           0
#
#          is_Wednesday  is_Thursday  is_Friday  is_holiday  is_business_hour
# 2608951             1            0          0           0                 0
# 2609172             1            0          0           0                 0
# 2609393             1            0          0           0                 0

# %%
meteo = pd.read_csv('MeteoBologna.csv')
meteo.head(2)
# Out:
#   LOCALITA        DATA  TMEDIA °C  TMIN °C  TMAX °C  PUNTORUGIADA °C  \
# 0  Bologna  16-04-2017         16       11       23               10
# 1  Bologna  17-04-2017         14       11       18                8
#
#    UMIDITA %  VISIBILITA km  VENTOMEDIA km-h  VENTOMAX km-h  RAFFICA km-h  \
# 0         70             21                7             17             0
# 1         68             19               14             24             0
#
#    PRESSIONESLM mb  PRESSIONEMEDIA mb  PIOGGIA mm            FENOMENI
# 0             1012                  0           0  pioggia temporale
# 1             1014                  0           0                 NaN

# %%
meteo_binary = {}
for index, row in meteo.iterrows():
    #print(row['DATA'], row['FENOMENI'])
    date = row['DATA']
    date2 = date.split('-')
    gg = date2[0]
    mm = date2[1]
    aaaa = date2[2]
    date = aaaa+'-'+mm+'-'+gg
    osservazione = str(row['FENOMENI'])
    if 'pioggia' in osservazione:
        meteo_binary[date] = 1
    else:  
        meteo_binary[date] = 0

# %%
rainy_shiny_days = []
for index, row in series.iterrows():
    date_i = row['date']
    meteo_bin_result = meteo_binary[date_i]
    rainy_shiny_days.append(meteo_bin_result)

series['is_rainy'] = rainy_shiny_days

# %%
series.head(3)
# Out:
#            date  cell_num  nr_people  hours  minutes  is_business_day  \
# 46   2017-04-16  488-1264      394.0    0.0      0.0                0
# 267  2017-04-16  488-1264      396.0    0.0     15.0                0
# 488  2017-04-16  488-1264      387.0    0.0     30.0                0
#
#      is_April  is_May  is_June  is_July  is_August  is_Monday  is_Tuesday  \
# 46          1       0        0        0          0          0           0
# 267         1       0        0        0          0          0           0
# 488         1       0        0        0          0          0           0
#
#      is_Wednesday  is_Thursday  is_Friday  is_holiday  is_business_hour  \
# 46              0            0          0           1                 0
# 267             0            0          0           1                 0
# 488             0            0          0           1                 0
#
#      is_rainy
# 46          1
# 267         1
# 488         1

# %%
data4deep = series[['hours', 'is_business_day', 'is_holiday', 'is_business_hour', 'is_rainy', 
                   'is_April', 'is_May', 'is_June', 'is_July', 'is_August', 'is_Monday', 'is_Tuesday', 
                    'is_Wednesday', 'is_Thursday', 'is_Friday']]
X = data4deep.values
y = series['nr_people'].values
print(type(X))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# #### Costruisco i lag

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
       
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# choose a number of time steps for the window
n_steps = 96

# data 
dati = series['nr_people'].values

# split into samples
X_lag, y_lag = split_sequence(dati, n_steps)

count = 0
# summarize the data
for i in range(len(X_lag)):
    count +=1
    if count > 2: 
        break
    print(X_lag[i], y_lag[i])
# Out:
# [394. 396. 387. 375. 365. 357. 349. 340. 332. 321. 306. 292. 292. 276.
#  265. 259. 253. 250. 246. 244. 245. 248. 254. 258. 258. 249. 236. 232.
#  236. 242. 251. 251. 267. 267. 267. 276. 278. 283. 283. 298. 315. 330.
#  336. 346. 337. 329. 327. 328. 338. 345. 351. 353. 356. 358. 369. 369.
#  377. 382. 391. 399. 410. 417. 417. 425. 432. 436. 434. 434. 453. 461.
#  461. 483. 475. 475. 455. 449. 445. 440. 440. 439. 434. 424. 416. 408.
#  408. 396. 396. 380. 380. 380. 380. 380. 372. 385. 382. 382.] 394.0
# [396. 387. 375. 365. 357. 349. 340. 332. 321. 306. 292. 292. 276. 265.
#  259. 253. 250. 246. 244. 245. 248. 254. 258. 258. 249. 236. 232. 236.
#  242. 251. 251. 267. 267. 267. 276. 278. 283. 283. 298. 315. 330. 336.
#  346. 337. 329. 327. 328. 338. 345. 351. 353. 356. 358. 369. 369. 377.
#  382. 391. 399. 410. 417. 417. 425. 432. 436. 434. 434. 453. 461. 461.
#  483. 475. 475. 455. 449. 445. 440. 440. 439. 434. 424. 416. 408. 408.
#  396. 396. 380. 380. 380. 380. 380. 372. 385. 382. 382. 394.] 394.0

# %%
print(len(X_lag))
print(len(y_lag))
# Out:
# 11712
# 11712

# %%
new_features = series[['is_holiday']]
X_new = new_features.values

# %%
X = np.concatenate((X_lag, X_new[0:len(X_lag)]),axis=1)
print(len(X))
# Out:
# 11712

# %%
y_final = y[0:len(X)]
len(y_final)
# Out:
# 11712

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y_final, test_size=0.2, random_state=1)
train_X, val_X, train_y, val_y = train_test_split(train_X, train_y, test_size=0.25, random_state=1)
print(len(train_X), len(train_y), len(test_X), len(test_y), len(val_X), len(val_y))
# Out:
# 7026 7026 2343 2343 2343 2343

# %%
print(train_X[0:])
# Out:
# [[273. 273. 273. ... 316. 308.   0.]
#  [478. 457. 445. ... 532. 532.   0.]
#  [472. 470. 470. ... 508. 500.   0.]
#  ...
#  [313. 343. 347. ... 278. 287.   0.]
#  [619. 619. 626. ... 621. 625.   0.]
#  [414. 423. 424. ... 488. 497.   1.]]

# %%
print(train_X)
print(test_y)
# Out:
# [[273. 273. 273. ... 316. 308.   0.]
#  [478. 457. 445. ... 532. 532.   0.]
#  [472. 470. 470. ... 508. 500.   0.]
#  ...
#  [313. 343. 347. ... 278. 287.   0.]
#  [619. 619. 626. ... 621. 625.   0.]
#  [414. 423. 424. ... 488. 497.   1.]]
# [280. 447. 470. ... 362. 523. 309.]

# %%
# define model
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=n_steps+1)) 
model.add(Dense(1))

model.compile(loss='mse',optimizer='adam', metrics=[metrics.mae, 'accuracy'])

model.fit(train_X, train_y, epochs=500, verbose=2)
# Out:
# Epoch 1/500
#  - 0s - loss: 5169.5408 - mean_absolute_error: 36.1276 - accuracy: 0.0139
# Epoch 2/500
#  - 0s - loss: 334.6830 - mean_absolute_error: 14.2993 - accuracy: 0.0241
# Epoch 3/500
#  - 0s - loss: 209.2443 - mean_absolute_error: 11.3575 - accuracy: 0.0273
# Epoch 4/500
#  - 0s - loss: 182.4646 - mean_absolute_error: 10.6692 - accuracy: 0.0312
# Epoch 5/500
#  - 0s - loss: 187.2395 - mean_absolute_error: 10.9118 - accuracy: 0.0280
# Epoch 6/500
#  - 0s - loss: 149.6857 - mean_absolute_error: 9.6766 - accuracy: 0.0323
# Epoch 7/500
#  - 0s - loss: 191.2003 - mean_absolute_error: 10.9870 - accuracy: 0.0299
# Epoch 8/500
#  - 0s - loss: 157.1384 - mean_absolute_error: 10.0479 - accuracy: 0.0327
# Epoch 9/500
#  - 0s - loss: 142.2366 - mean_absolute_error: 9.6070 - accuracy: 0.0349
# Epoch 10/500
#  - 0s - loss: 211.4084 - mean_absolute_error: 11.6362 - accuracy: 0.0280
# Epoch 11/500
#  - 0s - loss: 187.4672 - mean_absolute_error: 10.1115 - accuracy: 0.0347
# Epoch 12/500
#  - 0s - loss: 91.4898 - mean_absolute_error: 7.4852 - accuracy: 0.0416
# Epoch 13/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-2bf16ce61713> in <module>
#       6 model.compile(loss='mse',optimizer='adam', metrics=[metrics.mae, 'accuracy'])
#       7
# ----> 8 model.fit(train_X, train_y, epochs=500, verbose=2)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# compute error
predicted = np.array([])

for i in range(len(test_X)):
    x_input = test_X[i].reshape((1, n_steps+1))
    yhat = model.predict(x_input, verbose=0)
    predicted = np.append(predicted, yhat[0]) 

expected = test_y  
   
# abs difference
difference = abs((expected - predicted))

# %%
# show boxplot
print('Mean Absolute Error = ', np.mean(difference))
plt.figure(figsize = (15,1))
plt.boxplot(difference, vert= False);
plt.show()
plt.figure(figsize = (15,1))
plt.boxplot(series['nr_people'], vert= False);
plt.show()
# show series
plt.figure(figsize = (15,2))
series['nr_people'].plot()
plt.show()
# Out:
# Mean Absolute Error =  0.44503360867144154
