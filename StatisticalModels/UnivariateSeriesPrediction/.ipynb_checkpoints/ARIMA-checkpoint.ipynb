# %% [markdown]
# ### Autoregressive Integrated Moving Average Model - ARIMA
#
# <p> Reference : https://machinelearningmastery.com/make-manual-predictions-arima-models-python/ </p>

# %%
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
from pandas import datetime
from random import random
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.ar_model import AR
import warnings
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
warnings.filterwarnings('ignore')

from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt

# %% [markdown]
# ### Carica i dati e aggrega per cella

# %%
data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)
gbc = data.groupby(by = data['cell_num'])
cell_1 = gbc.get_group('486-1258')
cell_2 = gbc.get_group('498-1268')
cell_3 = gbc.get_group('488-1264')

# %% [markdown]
# ### Riassunto statistico sui dati

# %%
cell_3['nr_people'].describe()
# Out:
# count    11808.000000
# mean       419.686992
# std        101.311465
# min        220.000000
# 25%        326.000000
# 50%        421.000000
# 75%        500.000000
# max        676.000000
# Name: nr_people, dtype: float64

# %% [markdown]
# ### Modello ARIMA

# %%
def predict(coef, history):
    yhat = 0.0
    for i in range(1, len(coef)+1):
        yhat += coef[i-1] * history[-i]
    return yhat
 
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return np.array(diff)
 

X = cell_3['nr_people'].values
size = len(X) - 4000
train, test = X[0:size], X[size:]
history = [x for x in train]
predictions = list()
expected = list()
for t in range(len(test)):
    model = ARIMA(history, order=(4,1,2))
    model_fit = model.fit(trend='nc', disp=False)
    ar_coef, ma_coef = model_fit.arparams, model_fit.maparams
    resid = model_fit.resid
    diff = difference(history)
    yhat = history[-1] + predict(ar_coef, diff) + predict(ma_coef, resid)
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    expected.append(obs)
    print('>predicted=%.3f, expected=%.3f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# >predicted=312.960, expected=306.000
# >predicted=307.229, expected=307.000
# >predicted=307.855, expected=307.000
# >predicted=307.568, expected=333.000
# >predicted=339.738, expected=344.000
# >predicted=350.423, expected=356.000
# >predicted=362.811, expected=356.000
# >predicted=359.685, expected=368.000
# >predicted=373.663, expected=370.000
# >predicted=373.907, expected=389.000
# >predicted=396.484, expected=399.000
# >predicted=405.756, expected=420.000
# >predicted=429.596, expected=421.000
# >predicted=426.830, expected=414.000
# >predicted=416.574, expected=412.000
# >predicted=413.276, expected=410.000
# >predicted=411.249, expected=424.000
# >predicted=428.463, expected=433.000
# >predicted=438.063, expected=441.000
# >predicted=446.118, expected=446.000
# >predicted=450.192, expected=458.000
# >predicted=463.710, expected=458.000
# >predicted=461.575, expected=479.000
# >predicted=486.508, expected=507.000
# >predicted=518.136, expected=507.000
# >predicted=514.070, expected=529.000
# >predicted=538.406, expected=528.000
# >predicted=533.735, expected=536.000
# >predicted=542.238, expected=569.000
# >predicted=580.573, expected=576.000
# >predicted=585.473, expected=588.000
# >predicted=596.685, expected=588.000
# >predicted=593.471, expected=592.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e573ae792a16> in <module>
#      21 for t in range(len(test)):
#      22     model = ARIMA(history, order=(4,1,2))
# ---> 23     model_fit = model.fit(trend='nc', disp=False)
#      24     ar_coef, ma_coef = model_fit.arparams, model_fit.maparams
#      25     resid = model_fit.resid
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Calcolo dell'errore di previsione - grafico distribuzione errore

# %%
error = abs(np.array(predictions) - np.array(expected))
print('MSE ', error.mean())

plt.figure(figsize=(16, 1))
plt.boxplot(error, vert = False);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b70ed0956acd> in <module>
# ----> 1 error = abs(np.array(predictions) - np.array(expected))
#       2 print('MSE ', error.mean())
#       3
#       4 plt.figure(figsize=(16, 1))
#       5 plt.boxplot(error, vert = False);
#
# NameError: name 'predictions' is not defined

# %%
cell = '488-1264'
dict2data = {}
minimum = np.amin(error)   
per75 = np.percentile(error, 75)
per50 = np.percentile(error, 50)
per25 = np.percentile(error, 25)
maximum = np.amax(error)
l5i = [minimum, per25, per50, per75, maximum]
dict2data[cell] = l5i

with open('error_data_4_cell_488-1264_ARIMA_param_4.1.2.csv', 'w') as f:
    for key, value in dict2data.items():
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# ### Multistep (out-of-sample) forcasting con ARIMA

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)
 
    
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# load dataset
X = cell_3['nr_people'].values

days_in_year = 96
differenced = difference(X, days_in_year)

# fit model
model = ARIMA(differenced, order=(20,1,1))
model_fit = model.fit(disp=0)

# multi-step out-of-sample forecast
forecast = model_fit.forecast(steps=26)[0]

# invert the differenced forecast to something usable
history = [x for x in X]
day = 1
for yhat in forecast:
    inverted = inverse_difference(history, yhat, days_in_year)
    print('Day %d: %f' % (day, inverted))
    history.append(inverted)
    day += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-eab2d2a769eb> in <module>
#       7 # fit model
#       8 model = ARIMA(differenced, order=(20,1,1))
# ----> 9 model_fit = model.fit(disp=0)
#      10
#      11 # multi-step out-of-sample forecast
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# <__array_function__ internals> in pinv(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in pinv(a, rcond, hermitian)
#    1968         return wrap(res)
#    1969     a = a.conjugate()
# -> 1970     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1971
#    1972     # discard small singular values
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1634
#    1635         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1636         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1637         u = u.astype(result_t, copy=False)
#    1638         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Arima multistep forcast per tutte le celle

# %%
parameters = pd.read_csv('../BestARIMA_config_parametres.csv', header = None, sep = ':')
par_per_cell = {}
for index, row in parameters.iterrows(): 
    cell = row[0]
    rest = row[1]
    #print(rest)
    par = rest.split('),')
    #print(par[0])
    f_s = par[0]
    fs = f_s[2:]
    #print(fs)
    par_per_cell[cell] = fs
par_per_cell
# Out:
# {'491-1262': '4, 0, 1',
#  '490-1259': '8, 0, 2',
#  '493-1267': '4, 0, 2',
#  '496-1260': '4, 0, 1',
#  '489-1264': '8, 0, 0',
#  '486-1266': '8, 0, 1',
#  '498-1252': '2, 1, 2',
#  '486-1252': '4, 1, 2',
#  '497-1266': '2, 0, 0',
#  '496-1259': '2, 0, 2',
#  '497-1255': '2, 0, 0',
#  '495-1254': '4, 1, 1',
#  '486-1258': '4, 0, 1',
#  '486-1255': '2, 0, 1',
#  '487-1259': '8, 0, 2',
#  '487-1253': '4, 1, 2',
#  '495-1263': '4, 0, 1',
#  '492-1253': '8, 1, 2',
#  '492-1267': '4, 0, 2',
#  '493-1257': '2, 1, 2',
#  '495-1266': '4, 0, 2',
#  '496-1253': '2, 0, 0',
#  '489-1267': '2, 1, 2',
#  '493-1255': '4, 1, 2',
#  '486-1261': '8, 0, 1',
#  '488-1254': '4, 1, 2',
#  '491-1253': '4, 1, 2',
#  '488-1263': '8, 0, 2',
#  '491-1256': '4, 1, 2',
#  '493-1268': '2, 0, 1',
#  '491-1257': '4, 1, 2',
#  '494-1259': '8, 0, 2',
#  '494-1255': '8, 1, 2',
#  '487-1256': '4, 1, 2',
#  '496-1264': '4, 0, 1',
#  '487-1266': '8, 0, 0',
#  '490-1255': '4, 1, 2',
#  '490-1253': '4, 1, 2',
#  '490-1267': '4, 0, 2',
#  '493-1260': '8, 0, 1',
#  '492-1262': '8, 1, 2',
#  '493-1263': '4, 0, 1',
#  '497-1267': '2, 0, 1',
#  '489-1265': '8, 0, 0',
#  '492-1258': '2, 0, 1',
#  '498-1254': '2, 0, 0',
#  '493-1253': '8, 1, 2',
#  '491-1261': '8, 0, 2',
#  '491-1260': '8, 0, 1',
#  '498-1262': '2, 0, 2',
#  '486-1260': '8, 0, 1',
#  '492-1260': '4, 0, 1',
#  '488-1264': '8, 2, 2',
#  '498-1259': '2, 0, 0',
#  '487-1258': '4, 0, 2',
#  '497-1258': '2, 0, 0',
#  '495-1255': '2, 0, 1',
#  '493-1261': '8, 0, 2',
#  '488-1267': '2, 1, 2',
#  '488-1261': '8, 2, 2',
#  '486-1268': '2, 0, 2',
#  '490-1258': '4, 0, 2',
#  '497-1264': '2, 0, 0',
#  '493-1266': '4, 0, 1',
#  '488-1255': '4, 1, 2',
#  '494-1253': '4, 0, 1',
#  '487-1255': '4, 1, 2',
#  '495-1268': '2, 0, 1',
#  '492-1256': '4, 1, 2',
#  '496-1261': '2, 0, 0',
#  '490-1264': '8, 0, 0',
#  '491-1263': '4, 0, 1',
#  '488-1265': '8, 2, 2',
#  '490-1256': '4, 1, 2',
#  '498-1255': '2, 0, 0',
#  '489-1260': '8, 0, 2',
#  '487-1265': '8, 0, 1',
#  '487-1260': '8, 0, 2',
#  '498-1261': '2, 0, 0',
#  '491-1268': '4, 0, 2',
#  '487-1262': '8, 0, 1',
#  '490-1266': '8, 0, 1',
#  '498-1260': '2, 0, 0',
#  '494-1266': '2, 0, 0',
#  '494-1254': '2, 0, 2',
#  '488-1253': '4, 1, 2',
#  '494-1258': '2, 0, 1',
#  '495-1257': '4, 0, 0',
#  '489-1253': '4, 1, 2',
#  '493-1252': '4, 1, 2',
#  '495-1252': '2, 0, 2',
#  '486-1262': '8, 0, 2',
#  '492-1266': '4, 0, 2',
#  '490-1260': '8, 0, 2',
#  '496-1267': '2, 0, 1',
#  '495-1258': '2, 0, 1',
#  '489-1257': '8, 1, 2',
#  '487-1263': '8, 0, 2',
#  '496-1266': '4, 0, 1',
#  '497-1265': '2, 0, 1',
#  '489-1258': '4, 1, 2',
#  '498-1257': '2, 0, 0',
#  '489-1268': '4, 0, 2',
#  '486-1257': '4, 0, 1',
#  '488-1252': '4, 1, 2',
#  '494-1252': '2, 0, 0',
#  '498-1264': '0, 0, 1',
#  '498-1253': '2, 0, 1',
#  '494-1257': '2, 0, 1',
#  '494-1267': '8, 0, 2',
#  '493-1254': '8, 1, 2',
#  '492-1268': '4, 0, 2',
#  '495-1262': '4, 0, 1',
#  '493-1259': '8, 0, 2',
#  '495-1259': '2, 0, 1',
#  '493-1265': '4, 0, 2',
#  '489-1256': '8, 1, 2',
#  '490-1268': '2, 0, 1',
#  '490-1252': '8, 1, 2',
#  '487-1252': '2, 1, 2',
#  '498-1258': '2, 0, 0',
#  '488-1256': '4, 1, 2',
#  '498-1266': '4, 0, 2',
#  '498-1256': '2, 0, 0',
#  '494-1263': '8, 0, 0',
#  '488-1259': '8, 0, 2',
#  '486-1253': '8, 1, 2',
#  '491-1267': '8, 1, 2',
#  '486-1254': '2, 1, 2',
#  '491-1266': '2, 1, 2',
#  '486-1256': '2, 0, 2',
#  '493-1258': '2, 0, 1',
#  '493-1262': '8, 0, 2',
#  '495-1256': '2, 0, 1',
#  '486-1259': '8, 0, 2',
#  '491-1264': '8, 1, 1',
#  '497-1262': '2, 0, 1',
#  '492-1257': '2, 0, 1',
#  '498-1267': '2, 0, 2',
#  '496-1252': '2, 0, 0',
#  '491-1255': '4, 1, 2',
#  '490-1257': '4, 1, 2',
#  '497-1256': '2, 0, 0',
#  '490-1263': '8, 0, 2',
#  '497-1268': '2, 0, 0',
#  '496-1257': '2, 0, 0',
#  '496-1262': '4, 0, 2',
#  '486-1267': '4, 1, 2',
#  '495-1253': '2, 0, 0',
#  '498-1268': '4, 0, 0',
#  '497-1252': '2, 0, 1',
#  '494-1260': '8, 0, 2',
#  '492-1259': '8, 0, 2',
#  '495-1267': '2, 0, 0',
#  '497-1253': '2, 0, 2',
#  '487-1267': '8, 0, 2',
#  '495-1260': '2, 0, 1',
#  '496-1263': '2, 0, 1',
#  '488-1266': '2, 0, 1',
#  '495-1265': '4, 0, 1',
#  '492-1252': '8, 1, 2',
#  '490-1254': '4, 1, 2',
#  '496-1254': '2, 0, 0',
#  '492-1255': '4, 1, 2',
#  '488-1260': '8, 0, 2',
#  '497-1261': '2, 0, 0',
#  '491-1252': '8, 1, 2',
#  '489-1254': '4, 1, 2',
#  '496-1255': '2, 0, 0',
#  '489-1266': '4, 0, 2',
#  '491-1254': '4, 1, 2',
#  '497-1263': '4, 0, 1',
#  '487-1254': '4, 1, 2',
#  '491-1265': '4, 0, 2',
#  '496-1256': '2, 0, 0',
#  '488-1258': '4, 1, 2',
#  '490-1265': '8, 0, 1',
#  '494-1265': '4, 0, 2',
#  '491-1258': '4, 0, 2',
#  '496-1268': '2, 0, 0',
#  '492-1264': '4, 0, 2',
#  '487-1268': '2, 1, 2',
#  '491-1259': '8, 0, 2',
#  '492-1263': '8, 1, 2',
#  '487-1264': '8, 2, 2',
#  '489-1263': '8, 0, 2',
#  '494-1262': '8, 0, 0',
#  '489-1259': '8, 2, 2',
#  '486-1263': '8, 0, 1',
#  '498-1265': '2, 1, 2',
#  '493-1264': '4, 0, 2',
#  '492-1265': '4, 0, 2',
#  '494-1268': '4, 0, 2',
#  '493-1256': '2, 0, 1',
#  '494-1256': '2, 0, 1',
#  '497-1259': '2, 0, 1',
#  '496-1265': '2, 0, 2',
#  '486-1265': '8, 2, 2',
#  '495-1264': '4, 0, 1',
#  '488-1262': '8, 0, 0',
#  '489-1252': '4, 1, 2',
#  '489-1255': '4, 1, 2',
#  '497-1260': '4, 0, 0',
#  '497-1254': '2, 0, 0',
#  '494-1264': '2, 0, 1',
#  '497-1257': '2, 0, 0',
#  '487-1257': '4, 1, 2',
#  '489-1261': '8, 0, 2',
#  '492-1261': '4, 0, 2',
#  '488-1268': '4, 0, 2',
#  '492-1254': '4, 1, 2',
#  '488-1257': '4, 1, 2',
#  '495-1261': '4, 0, 1',
#  '490-1262': '8, 0, 2',
#  '494-1261': '4, 0, 1',
#  '489-1262': '8, 0, 2',
#  '486-1264': '8, 2, 2',
#  '487-1261': '8, 0, 2',
#  '498-1263': '2, 0, 2',
#  '490-1261': '8, 0, 2',
#  '496-1258': '2, 0, 1'}

# %%
predicted = []
count = 0
dict2data = {}
dict2MAPE = {}
for i, k in gbc:
    predicted = []
    cell = i
    param_per_cell_i = par_per_cell[cell]
    print(param_per_cell_i)
    print(count)
    count +=1
    #if count > 15: break
    series_i = k.iloc[::4, :]
    print('series length = ', len(series_i))
    series_i = series_i['nr_people'].values
    
    X, y = series_i[0: 2000], series_i[2000:]
    print(len(y))
    steps_forcast = len(y)
    print(len(X))
    days_in_year = 24
    differenced = difference(X, days_in_year)
    ar, ii, ma = param_per_cell_i.split(',')
    ar = int(ar)
    ii = int(ii)
    ma = int(ma)
    print('AR', ar)
    print('I', ii)
    print('MA', ma)
    # fit model
    model = ARIMA(differenced, order=(ar, ii, ma))
    model_fit = model.fit(disp=0)

    # multi-step out-of-sample forecast
    forecast = model_fit.forecast(steps=steps_forcast)[0]
    print('length forecast : ', len(forecast))
    # invert the differenced forecast to something usable
    history = [x for x in X]
    day = 1
    for yhat in forecast:
        inverted = inverse_difference(history, yhat, days_in_year)
        #print('Day %d: %f' % (day, inverted))
        history.append(inverted)
        day += 1
        
        predicted.append(inverted)
    
    
    plt.figure(figsize = (12, 4))
    plt.plot(predicted[:336], color='red', label='predicted')
    plt.plot(y[:336], color='green', label='expected')
    plt.legend();
    plt.show()
    
    predicted = np.array(predicted)    
    error = abs(predicted - y)
    
    MAPE = np.mean(abs(100*(error/y)))
    dict2MAPE[cell] = MAPE
    
    plt.figure(figsize=(16, 1))
    plt.boxplot(series_i, vert = False);
    plt.show()
    
    print('MAE ', np.mean(error))
    plt.figure(figsize=(16, 1))
    plt.boxplot(error, vert = False);
    plt.show()  
    # collect data 2 dictionary
    minimum = np.amin(error)   
    per75 = np.percentile(error, 75)
    per50 = np.percentile(error, 50)
    per25 = np.percentile(error, 25)
    maximum = np.amax(error)
    l5i = [minimum, per25, per50, per75, maximum]
    #l5i = ','.join(l5i)
    dict2data[cell] = l5i
# Out:
# 4, 1, 2
# 0
# series length =  2952
# 952
# 2000
# AR 4
# I 1
# MA 2
# length forecast :  952
# MAE  4.524390086225401
# 8, 1, 2
# 1
# series length =  2952
# 952
# 2000
# AR 8
# I 1
# MA 2
# length forecast :  952
# MAE  98.94077779805214
# 2, 1, 2
# 2
# series length =  2952
# 952
# 2000
# AR 2
# I 1
# MA 2
# length forecast :  952
# MAE  97.14536500942637
# 2, 0, 1
# 3
# series length =  2952
# 952
# 2000
# AR 2
# I 0
# MA 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0e13d39b2c78> in <module>
#      30     # fit model
#      31     model = ARIMA(differenced, order=(ar, ii, ma))
# ---> 32     model_fit = model.fit(disp=0)
#      33
#      34     # multi-step out-of-sample forecast
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Scrivi i dati errore in csv

# %%
with open('MAE_error_data_4_ARIMA_MultistepForcast_26.csv', 'w') as f:
    for key, value in dict2data.items():
        f.write('%s:%s\n' % (key, value))
        
with open('MAPE_error_data_4_ARIMA_MultistepForcast_26.csv', 'w') as f:
    for key, value in dict2MAPE.items():
        f.write('%s:%s\n' % (key, value))
