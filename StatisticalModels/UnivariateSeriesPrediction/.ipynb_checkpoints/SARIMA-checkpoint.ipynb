# %% [markdown]
# ### SARIMA

# %%
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
from pandas import datetime
from random import random
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.ar_model import AR
import warnings
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

warnings.filterwarnings('ignore')

from pandas import read_csv
from matplotlib import pyplot

from math import sqrt
import numpy

# %% [markdown]
# ### Carica dati

# %%
data = pd.read_csv('../../data/new_data_backfill_forwfill.csv',index_col = 0)
gbc = data.groupby(by = data['cell_num'])
cell_1 = gbc.get_group('486-1258')
cell_2 = gbc.get_group('498-1268')
cell_3 = gbc.get_group('488-1264')

# %%
def predict(coef, history):
    yhat = 0.0
    for i in range(1, len(coef)+1):
        yhat += coef[i-1] * history[-i]
    return yhat
 
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return numpy.array(diff)
 

X = cell_3['nr_people'].values
size = len(X) - 4000
train, test = X[0:size], X[size:]
history = [x for x in train]
predictions = list()
expected = list()
for t in range(len(test)):
    model = sm.tsa.statespace.SARIMAX(history, order=(1,1,1))
    model_fit = model.fit(trend='nc', disp=False)
    ar_coef, ma_coef = model_fit.arparams, model_fit.maparams
    resid = model_fit.resid
    diff = difference(history)
    yhat = history[-1] + predict(ar_coef, diff) + predict(ma_coef, resid)
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    expected.append(obs)
    print('>predicted=%.3f, expected=%.3f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# >predicted=312.905, expected=306.000
# >predicted=308.020, expected=307.000
# >predicted=308.587, expected=307.000
# >predicted=308.080, expected=333.000
# >predicted=339.242, expected=344.000
# >predicted=350.581, expected=356.000
# >predicted=363.023, expected=356.000
# >predicted=360.779, expected=368.000
# >predicted=373.796, expected=370.000
# >predicted=374.368, expected=389.000
# >predicted=396.001, expected=399.000
# >predicted=405.886, expected=420.000
# >predicted=429.141, expected=421.000
# >predicted=427.435, expected=414.000
# >predicted=416.895, expected=412.000
# >predicted=413.544, expected=410.000
# >predicted=410.625, expected=424.000
# >predicted=427.394, expected=433.000
# >predicted=437.217, expected=441.000
# >predicted=445.566, expected=446.000
# >predicted=450.168, expected=458.000
# >predicted=463.380, expected=458.000
# >predicted=461.663, expected=479.000
# >predicted=485.943, expected=507.000
# >predicted=517.666, expected=507.000
# >predicted=514.262, expected=529.000
# >predicted=538.610, expected=528.000
# >predicted=534.334, expected=536.000
# >predicted=542.010, expected=569.000
# >predicted=580.085, expected=576.000
# >predicted=585.041, expected=588.000
# >predicted=596.706, expected=588.000
# >predicted=593.937, expected=592.000
# >predicted=596.894, expected=592.000
# >predicted=595.336, expected=579.000
# >predicted=578.513, expected=572.000
# >predicted=570.181, expected=573.000
# >predicted=571.974, expected=579.000
# >predicted=579.573, expected=585.000
# >predicted=586.660, expected=581.000
# >predicted=581.284, expected=581.000
# >predicted=581.194, expected=576.000
# >predicted=575.073, expected=565.000
# >predicted=562.039, expected=565.000
# >predicted=562.983, expected=561.000
# >predicted=558.779, expected=561.000
# >predicted=559.487, expected=545.000
# >predicted=540.582, expected=536.000
# >predicted=531.084, expected=525.000
# >predicted=519.321, expected=527.000
# >predicted=523.556, expected=518.000
# >predicted=513.748, expected=493.000
# >predicted=484.807, expected=488.000
# >predicted=481.359, expected=488.000
# >predicted=483.476, expected=474.000
# >predicted=467.952, expected=474.000
# >predicted=469.879, expected=458.000
# >predicted=451.803, expected=441.000
# >predicted=433.176, expected=445.000
# >predicted=440.513, expected=447.000
# >predicted=444.365, expected=447.000
# >predicted=445.205, expected=449.000
# >predicted=448.200, expected=453.000
# >predicted=453.303, expected=454.000
# >predicted=454.418, expected=458.000
# >predicted=459.132, expected=458.000
# >predicted=458.771, expected=446.000
# >predicted=443.986, expected=433.000
# >predicted=428.875, expected=416.000
# >predicted=409.586, expected=405.000
# >predicted=398.299, expected=389.000
# >predicted=381.042, expected=389.000
# >predicted=383.584, expected=358.000
# >predicted=347.735, expected=358.000
# >predicted=351.009, expected=333.000
# >predicted=322.937, expected=325.000
# >predicted=316.446, expected=310.000
# >predicted=300.989, expected=310.000
# >predicted=303.860, expected=292.000
# >predicted=283.998, expected=283.000
# >predicted=275.637, expected=277.000
# >predicted=270.708, expected=267.000
# >predicted=260.591, expected=264.000
# >predicted=258.994, expected=264.000
# >predicted=260.588, expected=264.000
# >predicted=261.674, expected=279.000
# >predicted=280.600, expected=294.000
# >predicted=298.281, expected=299.000
# >predicted=302.975, expected=299.000
# >predicted=301.705, expected=299.000
# >predicted=300.841, expected=287.000
# >predicted=285.707, expected=281.000
# >predicted=278.846, expected=277.000
# >predicted=274.685, expected=279.000
# >predicted=277.849, expected=279.000
# >predicted=278.217, expected=306.000
# >predicted=311.198, expected=325.000
# >predicted=332.581, expected=331.000
# >predicted=337.429, expected=334.000
# >predicted=339.009, expected=334.000
# >predicted=337.406, expected=354.000
# >predicted=360.567, expected=354.000
# >predicted=358.467, expected=370.000
# >predicted=376.438, expected=390.000
# >predicted=398.631, expected=390.000
# >predicted=395.872, expected=426.000
# >predicted=437.645, expected=427.000
# >predicted=435.141, expected=427.000
# >predicted=432.543, expected=458.000
# >predicted=468.354, expected=458.000
# >predicted=465.059, expected=458.000
# >predicted=462.811, expected=443.000
# >predicted=443.090, expected=440.000
# >predicted=439.423, expected=436.000
# >predicted=434.757, expected=448.000
# >predicted=449.699, expected=457.000
# >predicted=460.064, expected=477.000
# >predicted=483.326, expected=473.000
# >predicted=476.462, expected=475.000
# >predicted=477.783, expected=489.000
# >predicted=493.861, expected=489.000
# >predicted=492.313, expected=516.000
# >predicted=523.974, expected=529.000
# >predicted=537.190, expected=529.000
# >predicted=534.583, expected=529.000
# >predicted=532.806, expected=556.000
# >predicted=564.310, expected=554.000
# >predicted=559.246, expected=537.000
# >predicted=536.980, expected=537.000
# >predicted=536.986, expected=537.000
# >predicted=536.991, expected=553.000
# >predicted=556.375, expected=560.000
# >predicted=563.782, expected=571.000
# >predicted=575.905, expected=568.000
# >predicted=570.713, expected=575.000
# >predicted=578.330, expected=578.000
# >predicted=580.906, expected=576.000
# >predicted=577.561, expected=576.000
# >predicted=577.065, expected=579.000
# >predicted=580.360, expected=583.000
# >predicted=584.773, expected=582.000
# >predicted=582.999, expected=571.000
# >predicted=569.358, expected=567.000
# >predicted=565.034, expected=567.000
# >predicted=565.659, expected=567.000
# >predicted=566.085, expected=567.000
# >predicted=566.376, expected=567.000
# >predicted=566.574, expected=473.000
# >predicted=452.862, expected=452.000
# >predicted=433.816, expected=444.000
# >predicted=429.913, expected=440.000
# >predicted=429.541, expected=440.000
# >predicted=432.866, expected=432.000
# >predicted=425.443, expected=422.000
# >predicted=415.414, expected=418.000
# >predicted=412.661, expected=430.000
# >predicted=428.896, expected=433.000
# >predicted=432.883, expected=429.000
# >predicted=428.075, expected=432.000
# >predicted=432.002, expected=432.000
# >predicted=432.002, expected=442.000
# >predicted=444.112, expected=442.000
# >predicted=443.440, expected=412.000
# >predicted=406.659, expected=392.000
# >predicted=384.131, expected=371.000
# >predicted=361.192, expected=356.000
# >predicted=346.144, expected=349.000
# >predicted=340.807, expected=341.000
# >predicted=333.728, expected=341.000
# >predicted=336.049, expected=341.000
# >predicted=337.631, expected=321.000
# >predicted=314.472, expected=310.000
# >predicted=303.226, expected=305.000
# >predicted=299.327, expected=292.000
# >predicted=285.385, expected=292.000
# >predicted=287.493, expected=281.000
# >predicted=275.602, expected=281.000
# >predicted=277.322, expected=275.000
# >predicted=271.225, expected=275.000
# >predicted=272.427, expected=271.000
# >predicted=268.401, expected=273.000
# >predicted=271.652, expected=274.000
# >predicted=273.293, expected=282.000
# >predicted=283.210, expected=288.000
# >predicted=290.094, expected=298.000
# >predicted=301.543, expected=298.000
# >predicted=300.412, expected=291.000
# >predicted=291.163, expected=290.000
# >predicted=289.899, expected=276.000
# >predicted=272.970, expected=276.000
# >predicted=273.937, expected=276.000
# >predicted=274.595, expected=272.000
# >predicted=270.197, expected=269.000
# >predicted=267.138, expected=269.000
# >predicted=267.732, expected=291.000
# >predicted=294.790, expected=304.000
# >predicted=309.335, expected=311.000
# >predicted=316.113, expected=325.000
# >predicted=331.446, expected=329.000
# >predicted=334.233, expected=324.000
# >predicted=326.501, expected=348.000
# >predicted=354.785, expected=353.000
# >predicted=358.677, expected=371.000
# >predicted=378.677, expected=378.000
# >predicted=384.709, expected=374.000
# >predicted=377.720, expected=362.000
# >predicted=361.986, expected=359.000
# >predicted=358.354, expected=359.000
# >predicted=358.560, expected=372.000
# >predicted=374.454, expected=381.000
# >predicted=384.575, expected=402.000
# >predicted=408.882, expected=420.000
# >predicted=428.500, expected=438.000
# >predicted=447.602, expected=438.000
# >predicted=444.528, expected=453.000
# >predicted=460.623, expected=453.000
# >predicted=458.184, expected=453.000
# >predicted=456.524, expected=485.000
# >predicted=494.182, expected=480.000
# >predicted=485.193, expected=491.000
# >predicted=496.865, expected=499.000
# >predicted=504.688, expected=508.000
# >predicted=513.779, expected=508.000
# >predicted=511.936, expected=515.000
# >predicted=519.163, expected=515.000
# >predicted=517.835, expected=517.000
# >predicted=519.354, expected=517.000
# >predicted=518.604, expected=539.000
# >predicted=544.743, expected=539.000
# >predicted=542.915, expected=551.000
# >predicted=556.204, expected=551.000
# >predicted=554.548, expected=538.000
# >predicted=537.671, expected=525.000
# >predicted=522.022, expected=519.000
# >predicted=515.701, expected=515.000
# >predicted=511.907, expected=515.000
# >predicted=512.894, expected=514.000
# >predicted=512.355, expected=518.000
# >predicted=517.726, expected=510.000
# >predicted=508.121, expected=510.000
# >predicted=508.720, expected=496.000
# >predicted=492.168, expected=490.000
# >predicted=486.121, expected=491.000
# >predicted=488.570, expected=474.000
# >predicted=468.749, expected=459.000
# >predicted=452.249, expected=456.000
# >predicted=450.768, expected=450.000
# >predicted=445.167, expected=449.000
# >predicted=445.497, expected=449.000
# >predicted=446.615, expected=453.000
# >predicted=452.223, expected=448.000
# >predicted=446.412, expected=448.000
# >predicted=446.919, expected=441.000
# >predicted=438.783, expected=437.000
# >predicted=434.644, expected=437.000
# >predicted=435.395, expected=413.000
# >predicted=406.832, expected=406.000
# >predicted=400.317, expected=403.000
# >predicted=398.495, expected=391.000
# >predicted=385.392, expected=370.000
# >predicted=361.736, expected=364.000
# >predicted=357.101, expected=364.000
# >predicted=359.300, expected=347.000
# >predicted=340.201, expected=347.000
# >predicted=342.367, expected=347.000
# >predicted=343.844, expected=347.000
# >predicted=344.850, expected=347.000
# >predicted=345.536, expected=347.000
# >predicted=346.003, expected=347.000
# >predicted=346.321, expected=347.000
# >predicted=346.537, expected=347.000
# >predicted=346.685, expected=347.000
# >predicted=346.785, expected=272.000
# >predicted=256.015, expected=264.000
# >predicted=251.425, expected=257.000
# >predicted=246.944, expected=257.000
# >predicted=250.138, expected=257.000
# >predicted=252.319, expected=269.000
# >predicted=268.345, expected=269.000
# >predicted=268.554, expected=284.000
# >predicted=286.868, expected=286.000
# >predicted=288.376, expected=280.000
# >predicted=280.352, expected=280.000
# >predicted=280.240, expected=280.000
# >predicted=280.163, expected=250.000
# >predicted=243.784, expected=250.000
# >predicted=245.765, expected=273.000
# >predicted=274.956, expected=273.000
# >predicted=274.333, expected=281.000
# >predicted=283.594, expected=280.000
# >predicted=281.559, expected=285.000
# >predicted=287.116, expected=285.000
# >predicted=286.443, expected=308.000
# >predicted=313.826, expected=304.000
# >predicted=307.131, expected=304.000
# >predicted=306.137, expected=320.000
# >predicted=324.823, expected=339.000
# >predicted=346.290, expected=375.000
# >predicted=387.569, expected=384.000
# >predicted=394.466, expected=388.000
# >predicted=395.978, expected=396.000
# >predicted=403.127, expected=396.000
# >predicted=400.857, expected=396.000
# >predicted=399.309, expected=376.000
# >predicted=374.021, expected=385.000
# >predicted=385.559, expected=393.000
# >predicted=395.068, expected=397.000
# >predicted=399.252, expected=407.000
# >predicted=410.642, expected=407.000
# >predicted=409.483, expected=421.000
# >predicted=425.642, expected=425.000
# >predicted=429.008, expected=433.000
# >predicted=437.418, expected=456.000
# >predicted=463.860, expected=454.000
# >predicted=458.937, expected=448.000
# >predicted=450.102, expected=464.000
# >predicted=468.804, expected=464.000
# >predicted=467.277, expected=464.000
# >predicted=466.236, expected=475.000
# >predicted=478.840, expected=475.000
# >predicted=477.620, expected=489.000
# >predicted=493.733, expected=496.000
# >predicted=500.703, expected=518.000
# >predicted=525.839, expected=534.000
# >predicted=542.720, expected=548.000
# >predicted=556.900, expected=559.000
# >predicted=567.390, expected=559.000
# >predicted=564.723, expected=548.000
# >predicted=549.580, expected=549.000
# >predicted=550.287, expected=554.000
# >predicted=555.932, expected=554.000
# >predicted=555.318, expected=575.000
# >predicted=580.321, expected=571.000
# >predicted=573.789, expected=548.000
# >predicted=545.060, expected=528.000
# >predicted=521.769, expected=504.000
# >predicted=494.673, expected=504.000
# >predicted=497.658, expected=491.000
# >predicted=483.936, expected=481.000
# >predicted=474.078, expected=469.000
# >predicted=461.752, expected=469.000
# >predicted=464.067, expected=469.000
# >predicted=465.643, expected=448.000
# >predicted=441.277, expected=451.000
# >predicted=447.055, expected=451.000
# >predicted=448.314, expected=435.000
# >predicted=429.793, expected=435.000
# >predicted=431.452, expected=437.000
# >predicted=435.005, expected=430.000
# >predicted=427.164, expected=438.000
# >predicted=437.756, expected=456.000
# >predicted=459.637, expected=456.000
# >predicted=458.475, expected=437.000
# >predicted=434.679, expected=437.000
# >predicted=435.419, expected=425.000
# >predicted=421.393, expected=400.000
# >predicted=392.265, expected=374.000
# >predicted=363.229, expected=364.000
# >predicted=354.558, expected=359.000
# >predicted=351.520, expected=355.000
# >predicted=349.066, expected=348.000
# >predicted=342.482, expected=341.000
# >predicted=335.765, expected=341.000
# >predicted=337.440, expected=323.000
# >predicted=316.770, expected=323.000
# >predicted=318.760, expected=323.000
# >predicted=320.115, expected=297.000
# >predicted=289.543, expected=298.000
# >predicted=293.132, expected=290.000
# >predicted=284.995, expected=289.000
# >predicted=285.380, expected=289.000
# >predicted=286.534, expected=281.000
# >predicted=277.632, expected=281.000
# >predicted=278.705, expected=288.000
# >predicted=287.915, expected=288.000
# >predicted=287.942, expected=305.000
# >predicted=308.552, expected=308.000
# >predicted=311.051, expected=302.000
# >predicted=302.811, expected=282.000
# >predicted=278.331, expected=269.000
# >predicted=263.754, expected=273.000
# >predicted=270.275, expected=269.000
# >predicted=266.300, expected=276.000
# >predicted=275.639, expected=295.000
# >predicted=298.769, expected=299.000
# >predicted=302.410, expected=299.000
# >predicted=301.320, expected=323.000
# >predicted=329.650, expected=323.000
# >predicted=327.524, expected=323.000
# >predicted=326.079, expected=323.000
# >predicted=325.096, expected=323.000
# >predicted=324.426, expected=393.000
# >predicted=408.724, expected=393.000
# >predicted=403.704, expected=414.000
# >predicted=425.723, expected=428.000
# >predicted=438.946, expected=439.000
# >predicted=448.786, expected=438.000
# >predicted=444.465, expected=438.000
# >predicted=442.407, expected=467.000
# >predicted=476.109, expected=488.000
# >predicted=498.635, expected=486.000
# >predicted=492.846, expected=482.000
# >predicted=485.833, expected=482.000
# >predicted=484.616, expected=492.000
# >predicted=495.888, expected=492.000
# >predicted=494.656, expected=503.000
# >predicted=507.123, expected=509.000
# >predicted=513.076, expected=514.000
# >predicted=517.834, expected=528.000
# >predicted=533.556, expected=528.000
# >predicted=531.798, expected=542.000
# >predicted=547.531, expected=542.000
# >predicted=545.781, expected=583.000
# >predicted=594.175, expected=583.000
# >predicted=590.645, expected=563.000
# >predicted=564.048, expected=561.000
# >predicted=561.297, expected=563.000
# >predicted=563.622, expected=574.000
# >predicted=576.725, expected=579.000
# >predicted=581.910, expected=580.000
# >predicted=582.202, expected=582.000
# >predicted=583.925, expected=583.000
# >predicted=584.527, expected=585.000
# >predicted=586.463, expected=587.000
# >predicted=588.420, expected=594.000
# >predicted=596.434, expected=591.000
# >predicted=592.040, expected=579.000
# >predicted=577.205, expected=576.000
# >predicted=574.144, expected=571.000
# >predicted=568.685, expected=558.000
# >predicted=553.697, expected=546.000
# >predicted=540.545, expected=537.000
# >predicted=531.385, expected=537.000
# >predicted=533.159, expected=537.000
# >predicted=534.372, expected=537.000
# >predicted=535.202, expected=515.000
# >predicted=509.169, expected=508.000
# >predicted=502.546, expected=508.000
# >predicted=504.267, expected=478.000
# >predicted=469.174, expected=482.000
# >predicted=476.792, expected=481.000
# >predicted=477.224, expected=481.000
# >predicted=478.415, expected=476.000
# >predicted=473.185, expected=469.000
# >predicted=465.610, expected=460.000
# >predicted=455.799, expected=464.000
# >predicted=461.957, expected=464.000
# >predicted=462.601, expected=462.000
# >predicted=460.624, expected=449.000
# >predicted=445.345, expected=449.000
# >predicted=446.495, expected=449.000
# >predicted=447.284, expected=405.000
# >predicted=394.651, expected=397.000
# >predicted=388.237, expected=384.000
# >predicted=375.280, expected=368.000
# >predicted=358.683, expected=354.000
# >predicted=344.690, expected=344.000
# >predicted=335.530, expected=336.000
# >predicted=328.524, expected=330.000
# >predicted=323.623, expected=330.000
# >predicted=325.630, expected=304.000
# >predicted=295.577, expected=301.000
# >predicted=294.595, expected=302.000
# >predicted=297.815, expected=302.000
# >predicted=299.131, expected=294.000
# >predicted=290.363, expected=294.000
# >predicted=291.505, expected=294.000
# >predicted=292.289, expected=277.000
# >predicted=272.285, expected=276.000
# >predicted=272.555, expected=281.000
# >predicted=279.677, expected=298.000
# >predicted=300.637, expected=303.000
# >predicted=305.851, expected=305.000
# >predicted=307.372, expected=297.000
# >predicted=296.960, expected=293.000
# >predicted=292.140, expected=289.000
# >predicted=287.577, expected=289.000
# >predicted=288.024, expected=289.000
# >predicted=288.330, expected=280.000
# >predicted=277.666, expected=291.000
# >predicted=291.689, expected=291.000
# >predicted=291.473, expected=309.000
# >predicted=313.074, expected=328.000
# >predicted=334.758, expected=345.000
# >predicted=353.184, expected=345.000
# >predicted=350.606, expected=358.000
# >predicted=364.556, expected=365.000
# >predicted=370.954, expected=378.000
# >predicted=384.795, expected=378.000
# >predicted=382.657, expected=385.000
# >predicted=389.653, expected=396.000
# >predicted=401.485, expected=425.000
# >predicted=434.813, expected=435.000
# >predicted=443.817, expected=431.000
# >predicted=436.210, expected=428.000
# >predicted=430.944, expected=439.000
# >predicted=443.315, expected=439.000
# >predicted=441.959, expected=439.000
# >predicted=441.029, expected=442.000
# >predicted=444.017, expected=442.000
# >predicted=443.383, expected=449.000
# >predicted=451.408, expected=463.000
# >predicted=467.570, expected=483.000
# >predicted=490.306, expected=483.000
# >predicted=488.010, expected=483.000
# >predicted=486.436, expected=536.000
# >predicted=549.397, expected=551.000
# >predicted=563.325, expected=551.000
# >predicted=559.460, expected=568.000
# >predicted=577.351, expected=577.000
# >predicted=585.297, expected=586.000
# >predicted=593.573, expected=586.000
# >predicted=591.199, expected=587.000
# >predicted=590.777, expected=585.000
# >predicted=587.174, expected=581.000
# >predicted=581.657, expected=580.000
# >predicted=580.242, expected=580.000
# >predicted=580.166, expected=572.000
# >predicted=570.446, expected=572.000
# >predicted=570.934, expected=559.000
# >predicted=555.559, expected=557.000
# >predicted=554.223, expected=557.000
# >predicted=555.095, expected=557.000
# >predicted=555.693, expected=589.000
# >predicted=594.774, expected=609.000
# >predicted=617.143, expected=610.000
# >predicted=615.785, expected=610.000
# >predicted=613.965, expected=608.000
# >predicted=610.300, expected=608.000
# >predicted=609.576, expected=580.000
# >predicted=575.230, expected=564.000
# >predicted=557.380, expected=554.000
# >predicted=547.377, expected=554.000
# >predicted=549.470, expected=527.000
# >predicted=518.250, expected=512.000
# >predicted=502.871, expected=512.000
# >predicted=505.756, expected=502.000
# >predicted=495.635, expected=492.000
# >predicted=485.551, expected=489.000
# >predicted=483.960, expected=476.000
# >predicted=469.829, expected=476.000
# >predicted=471.778, expected=476.000
# >predicted=473.112, expected=497.000
# >predicted=499.430, expected=497.000
# >predicted=498.659, expected=488.000
# >predicted=487.250, expected=463.000
# >predicted=457.257, expected=440.000
# >predicted=431.251, expected=436.000
# >predicted=429.181, expected=436.000
# >predicted=431.338, expected=436.000
# >predicted=432.812, expected=413.000
# >predicted=406.004, expected=399.000
# >predicted=391.283, expected=386.000
# >predicted=377.998, expected=376.000
# >predicted=368.431, expected=367.000
# >predicted=359.937, expected=351.000
# >predicted=342.815, expected=342.000
# >predicted=334.515, expected=333.000
# >predicted=325.993, expected=323.000
# >predicted=316.110, expected=315.000
# >predicted=308.609, expected=309.000
# >predicted=303.370, expected=304.000
# >predicted=299.100, expected=304.000
# >predicted=300.648, expected=299.000
# >predicted=295.659, expected=305.000
# >predicted=303.972, expected=315.000
# >predicted=316.395, expected=334.000
# >predicted=338.947, expected=341.000
# >predicted=345.850, expected=340.000
# >predicted=343.102, expected=332.000
# >predicted=332.442, expected=318.000
# >predicted=315.363, expected=313.000
# >predicted=310.148, expected=312.000
# >predicted=309.843, expected=313.000
# >predicted=311.736, expected=309.000
# >predicted=307.297, expected=314.000
# >predicted=313.886, expected=320.000
# >predicted=321.182, expected=320.000
# >predicted=320.807, expected=320.000
# >predicted=320.551, expected=333.000
# >predicted=336.105, expected=340.000
# >predicted=343.591, expected=340.000
# >predicted=342.452, expected=340.000
# >predicted=341.675, expected=340.000
# >predicted=341.144, expected=387.000
# >predicted=397.641, expected=390.000
# >predicted=397.897, expected=390.000
# >predicted=395.399, expected=420.000
# >predicted=429.977, expected=420.000
# >predicted=426.825, expected=419.000
# >predicted=423.459, expected=422.000
# >predicted=425.678, expected=412.000
# >predicted=412.418, expected=415.000
# >predicted=415.915, expected=415.000
# >predicted=415.626, expected=415.000
# >predicted=415.428, expected=416.000
# >predicted=416.502, expected=419.000
# >predicted=419.971, expected=428.000
# >predicted=430.548, expected=431.000
# >predicted=433.371, expected=431.000
# >predicted=432.621, expected=467.000
# >predicted=475.643, expected=467.000
# >predicted=472.911, expected=482.000
# >predicted=489.183, expected=504.000
# >predicted=513.521, expected=526.000
# >predicted=537.125, expected=543.000
# >predicted=554.174, expected=543.000
# >predicted=550.641, expected=554.000
# >predicted=561.532, expected=562.000
# >predicted=568.829, expected=551.000
# >predicted=553.359, expected=551.000
# >predicted=552.611, expected=557.000
# >predicted=559.360, expected=557.000
# >predicted=558.613, expected=564.000
# >predicted=566.570, expected=561.000
# >predicted=562.129, expected=542.000
# >predicted=538.786, expected=542.000
# >predicted=539.805, expected=532.000
# >predicted=528.403, expected=533.000
# >predicted=530.752, expected=530.000
# >predicted=527.835, expected=533.000
# >predicted=532.149, expected=514.000
# >predicted=509.437, expected=508.000
# >predicted=503.623, expected=506.000
# >predicted=502.589, expected=506.000
# >predicted=503.669, expected=490.000
# >predicted=485.054, expected=471.000
# >predicted=463.636, expected=452.000
# >predicted=442.979, expected=437.000
# >predicted=427.686, expected=428.000
# >predicted=419.747, expected=428.000
# >predicted=422.361, expected=428.000
# >predicted=424.149, expected=416.000
# >predicted=410.848, expected=416.000
# >predicted=412.480, expected=402.000
# >predicted=396.656, expected=396.000
# >predicted=391.089, expected=390.000
# >predicted=385.384, expected=395.000
# >predicted=392.894, expected=412.000
# >predicted=414.133, expected=416.000
# >predicted=418.298, expected=406.000
# >predicted=405.470, expected=392.000
# >predicted=388.702, expected=367.000
# >predicted=359.498, expected=358.000
# >predicted=350.986, expected=358.000
# >predicted=353.210, expected=343.000
# >predicted=336.579, expected=338.000
# >predicted=332.564, expected=340.000
# >predicted=336.707, expected=340.000
# >predicted=337.751, expected=333.000
# >predicted=329.994, expected=327.000
# >predicted=323.687, expected=317.000
# >predicted=312.638, expected=310.000
# >predicted=305.551, expected=296.000
# >predicted=290.022, expected=296.000
# >predicted=291.915, expected=283.000
# >predicted=277.481, expected=283.000
# >predicted=279.228, expected=271.000
# >predicted=265.904, expected=275.000
# >predicted=272.356, expected=269.000
# >predicted=265.934, expected=269.000
# >predicted=266.905, expected=269.000
# >predicted=267.568, expected=269.000
# >predicted=268.021, expected=294.000
# >predicted=298.580, expected=297.000
# >predicted=300.758, expected=287.000
# >predicted=287.469, expected=272.000
# >predicted=269.175, expected=269.000
# >predicted=266.441, expected=269.000
# >predicted=267.251, expected=269.000
# >predicted=267.805, expected=285.000
# >predicted=287.538, expected=285.000
# >predicted=286.734, expected=310.000
# >predicted=316.430, expected=315.000
# >predicted=320.441, expected=323.000
# >predicted=328.396, expected=335.000
# >predicted=341.205, expected=350.000
# >predicted=357.388, expected=359.000
# >predicted=365.936, expected=354.000
# >predicted=357.687, expected=346.000
# >predicted=346.835, expected=356.000
# >predicted=358.672, expected=356.000
# >predicted=357.825, expected=398.000
# >predicted=408.052, expected=406.000
# >predicted=414.548, expected=409.000
# >predicted=415.473, expected=417.000
# >predicted=423.102, expected=417.000
# >predicted=421.172, expected=417.000
# >predicted=419.851, expected=421.000
# >predicted=423.788, expected=441.000
# >predicted=447.096, expected=441.000
# >predicted=445.170, expected=454.000
# >predicted=459.574, expected=454.000
# >predicted=457.813, expected=479.000
# >predicted=486.841, expected=493.000
# >predicted=501.298, expected=522.000
# >predicted=533.756, expected=532.000
# >predicted=542.139, expected=527.000
# >predicted=532.889, expected=527.000
# >predicted=531.026, expected=555.000
# >predicted=563.621, expected=558.000
# >predicted=564.532, expected=565.000
# >predicted=570.938, expected=561.000
# >predicted=564.229, expected=551.000
# >predicted=551.113, expected=551.000
# >predicted=551.078, expected=568.000
# >predicted=571.609, expected=568.000
# >predicted=570.472, expected=566.000
# >predicted=567.275, expected=563.000
# >predicted=563.246, expected=563.000
# >predicted=563.169, expected=568.000
# >predicted=569.160, expected=564.000
# >predicted=563.959, expected=574.000
# >predicted=576.061, expected=583.000
# >predicted=586.292, expected=583.000
# >predicted=585.255, expected=571.000
# >predicted=570.038, expected=546.000
# >predicted=540.110, expected=546.000
# >predicted=541.971, expected=532.000
# >predicted=526.313, expected=532.000
# >predicted=528.108, expected=528.000
# >predicted=524.499, expected=506.000
# >predicted=499.004, expected=493.000
# >predicted=485.490, expected=475.000
# >predicted=466.091, expected=468.000
# >predicted=460.437, expected=459.000
# >predicted=451.939, expected=459.000
# >predicted=454.168, expected=442.000
# >predicted=435.133, expected=440.000
# >predicted=434.880, expected=440.000
# >predicted=436.495, expected=440.000
# >predicted=437.601, expected=440.000
# >predicted=438.359, expected=437.000
# >predicted=435.249, expected=437.000
# >predicted=435.801, expected=457.000
# >predicted=460.368, expected=457.000
# >predicted=459.303, expected=416.000
# >predicted=409.015, expected=416.000
# >predicted=411.216, expected=416.000
# >predicted=412.721, expected=399.000
# >predicted=393.207, expected=393.000
# >predicted=387.777, expected=393.000
# >predicted=389.420, expected=387.000
# >predicted=383.294, expected=373.000
# >predicted=367.540, expected=358.000
# >predicted=351.127, expected=348.000
# >predicted=341.201, expected=341.000
# >predicted=334.878, expected=328.000
# >predicted=321.090, expected=314.000
# >predicted=306.340, expected=305.000
# >predicted=297.869, expected=296.000
# >predicted=289.232, expected=292.000
# >predicted=286.525, expected=292.000
# >predicted=288.247, expected=292.000
# >predicted=289.428, expected=276.000
# >predicted=270.896, expected=272.000
# >predicted=267.665, expected=272.000
# >predicted=269.027, expected=289.000
# >predicted=290.512, expected=291.000
# >predicted=292.454, expected=297.000
# >predicted=299.250, expected=300.000
# >predicted=302.168, expected=290.000
# >predicted=289.399, expected=293.000
# >predicted=293.214, expected=284.000
# >predicted=282.269, expected=273.000
# >predicted=269.518, expected=279.000
# >predicted=277.865, expected=290.000
# >predicted=291.517, expected=309.000
# >predicted=314.008, expected=309.000
# >predicted=312.430, expected=316.000
# >predicted=319.812, expected=334.000
# >predicted=340.371, expected=332.000
# >predicted=335.947, expected=332.000
# >predicted=334.705, expected=348.000
# >predicted=353.193, expected=366.000
# >predicted=373.317, expected=367.000
# >predicted=372.224, expected=367.000
# >predicted=370.581, expected=396.000
# >predicted=404.505, expected=425.000
# >predicted=436.891, expected=433.000
# >predicted=442.822, expected=431.000
# >predicted=437.316, expected=431.000
# >predicted=435.328, expected=440.000
# >predicted=444.847, expected=438.000
# >predicted=440.904, expected=443.000
# >predicted=446.035, expected=443.000
# >predicted=445.080, expected=452.000
# >predicted=455.305, expected=461.000
# >predicted=465.144, expected=472.000
# >predicted=477.136, expected=479.000
# >predicted=483.983, expected=477.000
# >predicted=480.000, expected=499.000
# >predicted=505.646, expected=524.000
# >predicted=533.777, expected=534.000
# >predicted=542.793, expected=534.000
# >predicted=540.031, expected=525.000
# >predicted=527.254, expected=520.000
# >predicted=520.498, expected=528.000
# >predicted=530.013, expected=528.000
# >predicted=529.380, expected=538.000
# >predicted=541.033, expected=543.000
# >predicted=546.123, expected=541.000
# >predicted=542.724, expected=553.000
# >predicted=556.685, expected=548.000
# >predicted=549.485, expected=550.000
# >predicted=551.436, expected=556.000
# >predicted=558.236, expected=556.000
# >predicted=557.534, expected=562.000
# >predicted=564.303, expected=569.000
# >predicted=572.039, expected=577.000
# >predicted=580.753, expected=577.000
# >predicted=579.574, expected=563.000
# >predicted=561.847, expected=563.000
# >predicted=562.209, expected=563.000
# >predicted=562.458, expected=556.000
# >predicted=554.169, expected=539.000
# >predicted=534.197, expected=521.000
# >predicted=513.947, expected=501.000
# >predicted=491.983, expected=482.000
# >predicted=471.845, expected=466.000
# >predicted=455.695, expected=449.000
# >predicted=438.382, expected=449.000
# >predicted=441.735, expected=433.000
# >predicted=424.672, expected=433.000
# >predicted=427.301, expected=426.000
# >predicted=420.632, expected=420.000
# >predicted=415.068, expected=410.000
# >predicted=404.529, expected=402.000
# >predicted=396.578, expected=414.000
# >predicted=412.802, expected=430.000
# >predicted=432.542, expected=448.000
# >predicted=453.527, expected=448.000
# >predicted=451.773, expected=412.000
# >predicted=407.041, expected=394.000
# >predicted=386.829, expected=388.000
# >predicted=381.840, expected=382.000
# >predicted=376.530, expected=377.000
# >predicted=372.212, expected=371.000
# >predicted=366.468, expected=351.000
# >predicted=343.707, expected=346.000
# >predicted=339.965, expected=346.000
# >predicted=341.873, expected=346.000
# >predicted=343.179, expected=319.000
# >predicted=311.412, expected=311.000
# >predicted=304.132, expected=302.000
# >predicted=295.414, expected=297.000
# >predicted=291.446, expected=290.000
# >predicted=284.733, expected=288.000
# >predicted=283.977, expected=288.000
# >predicted=285.248, expected=282.000
# >predicted=278.860, expected=278.000
# >predicted=275.013, expected=280.000
# >predicted=278.375, expected=274.000
# >predicted=271.631, expected=274.000
# >predicted=272.379, expected=302.000
# >predicted=306.759, expected=304.000
# >predicted=307.673, expected=309.000
# >predicted=312.560, expected=309.000
# >predicted=311.435, expected=309.000
# >predicted=310.666, expected=299.000
# >predicted=298.045, expected=290.000
# >predicted=287.460, expected=278.000
# >predicted=273.746, expected=282.000
# >predicted=279.931, expected=281.000
# >predicted=279.376, expected=281.000
# >predicted=279.889, expected=289.000
# >predicted=289.917, expected=299.000
# >predicted=301.724, expected=319.000
# >predicted=325.060, expected=331.000
# >predicted=337.662, expected=339.000
# >predicted=345.230, expected=348.000
# >predicted=354.146, expected=351.000
# >predicted=355.827, expected=365.000
# >predicted=371.238, expected=363.000
# >predicted=366.841, expected=364.000
# >predicted=366.833, expected=387.000
# >predicted=393.765, expected=383.000
# >predicted=386.784, expected=383.000
# >predicted=385.586, expected=393.000
# >predicted=396.865, expected=390.000
# >predicted=392.013, expected=390.000
# >predicted=391.376, expected=390.000
# >predicted=390.940, expected=414.000
# >predicted=419.674, expected=432.000
# >predicted=439.655, expected=427.000
# >predicted=431.185, expected=427.000
# >predicted=429.862, expected=464.000
# >predicted=473.706, expected=468.000
# >predicted=475.480, expected=479.000
# >predicted=486.423, expected=503.000
# >predicted=513.109, expected=514.000
# >predicted=523.225, expected=533.000
# >predicted=543.297, expected=537.000
# >predicted=544.887, expected=536.000
# >predicted=541.188, expected=529.000
# >predicted=531.077, expected=515.000
# >predicted=513.472, expected=512.000
# >predicted=510.325, expected=515.000
# >predicted=514.486, expected=519.000
# >predicted=519.488, expected=519.000
# >predicted=519.334, expected=556.000
# >predicted=563.985, expected=561.000
# >predicted=567.507, expected=553.000
# >predicted=555.774, expected=532.000
# >predicted=529.494, expected=532.000
# >predicted=530.288, expected=519.000
# >predicted=515.103, expected=519.000
# >predicted=516.337, expected=519.000
# >predicted=517.180, expected=548.000
# >predicted=552.830, expected=544.000
# >predicted=546.462, expected=544.000
# >predicted=545.684, expected=528.000
# >predicted=525.805, expected=517.000
# >predicted=513.195, expected=496.000
# >predicted=488.995, expected=485.000
# >predicted=477.906, expected=485.000
# >predicted=480.153, expected=477.000
# >predicted=472.011, expected=468.000
# >predicted=462.704, expected=453.000
# >predicted=446.235, expected=439.000
# >predicted=431.440, expected=434.000
# >predicted=427.785, expected=434.000
# >predicted=429.753, expected=435.000
# >predicted=432.309, expected=433.000
# >predicted=430.742, expected=428.000
# >predicted=425.408, expected=424.000
# >predicted=421.390, expected=430.000
# >predicted=429.475, expected=434.000
# >predicted=434.481, expected=435.000
# >predicted=435.538, expected=424.000
# >predicted=422.061, expected=412.000
# >predicted=408.159, expected=385.000
# >predicted=376.708, expected=385.000
# >predicted=379.338, expected=355.000
# >predicted=344.835, expected=355.000
# >predicted=348.057, expected=355.000
# >predicted=350.256, expected=339.000
# >predicted=332.402, expected=332.000
# >predicted=326.022, expected=323.000
# >predicted=317.027, expected=307.000
# >predicted=299.561, expected=307.000
# >predicted=301.914, expected=287.000
# >predicted=279.330, expected=278.000
# >predicted=270.868, expected=272.000
# >predicted=265.864, expected=271.000
# >predicted=266.594, expected=271.000
# >predicted=267.988, expected=274.000
# >predicted=272.571, expected=277.000
# >predicted=276.653, expected=275.000
# >predicted=274.343, expected=283.000
# >predicted=284.229, expected=291.000
# >predicted=293.518, expected=292.000
# >predicted=293.931, expected=297.000
# >predicted=299.368, expected=289.000
# >predicted=288.941, expected=274.000
# >predicted=270.813, expected=273.000
# >predicted=270.613, expected=271.000
# >predicted=268.950, expected=271.000
# >predicted=269.599, expected=282.000
# >predicted=283.349, expected=289.000
# >predicted=291.391, expected=300.000
# >predicted=303.942, expected=302.000
# >predicted=305.112, expected=292.000
# >predicted=292.028, expected=306.000
# >predicted=308.955, expected=316.000
# >predicted=320.116, expected=316.000
# >predicted=318.813, expected=340.000
# >predicted=346.955, expected=347.000
# >predicted=353.221, expected=377.000
# >predicted=387.549, expected=395.000
# >predicted=405.991, expected=404.000
# >predicted=413.398, expected=423.000
# >predicted=433.414, expected=432.000
# >predicted=441.006, expected=416.000
# >predicted=418.780, expected=413.000
# >predicted=414.262, expected=409.000
# >predicted=409.016, expected=412.000
# >predicted=412.643, expected=423.000
# >predicted=425.752, expected=423.000
# >predicted=424.878, expected=423.000
# >predicted=424.282, expected=423.000
# >predicted=423.875, expected=433.000
# >predicted=435.699, expected=436.000
# >predicted=438.472, expected=436.000
# >predicted=437.688, expected=460.000
# >predicted=466.194, expected=486.000
# >predicted=495.700, expected=490.000
# >predicted=497.459, expected=504.000
# >predicted=512.036, expected=523.000
# >predicted=532.483, expected=519.000
# >predicted=524.629, expected=521.000
# >predicted=525.262, expected=525.000
# >predicted=528.749, expected=525.000
# >predicted=527.558, expected=533.000
# >predicted=536.429, expected=525.000
# >predicted=525.656, expected=540.000
# >predicted=543.603, expected=558.000
# >predicted=564.242, expected=554.000
# >predicted=557.422, expected=554.000
# >predicted=556.337, expected=555.000
# >predicted=556.805, expected=555.000
# >predicted=556.233, expected=558.000
# >predicted=559.472, expected=558.000
# >predicted=559.005, expected=567.000
# >predicted=569.576, expected=558.000
# >predicted=557.870, expected=555.000
# >predicted=554.281, expected=535.000
# >predicted=530.306, expected=527.000
# >predicted=522.114, expected=520.000
# >predicted=515.193, expected=509.000
# >predicted=503.406, expected=498.000
# >predicted=491.869, expected=491.000
# >predicted=485.344, expected=477.000
# >predicted=470.195, expected=472.000
# >predicted=466.305, expected=470.000
# >predicted=465.693, expected=470.000
# >predicted=467.062, expected=484.000
# >predicted=484.947, expected=484.000
# >predicted=484.645, expected=469.000
# >predicted=466.283, expected=455.000
# >predicted=450.202, expected=442.000
# >predicted=435.990, expected=453.000
# >predicted=451.214, expected=456.000
# >predicted=455.413, expected=464.000
# >predicted=465.283, expected=470.000
# >predicted=472.139, expected=470.000
# >predicted=471.458, expected=432.000
# >predicted=425.008, expected=423.000
# >predicted=416.336, expected=410.000
# >predicted=402.718, expected=398.000
# >predicted=390.507, expected=383.000
# >predicted=374.732, expected=360.000
# >predicted=349.515, expected=352.000
# >predicted=343.165, expected=345.000
# >predicted=337.501, expected=340.000
# >predicted=333.834, expected=334.000
# >predicted=328.532, expected=321.000
# >predicted=314.531, expected=321.000
# >predicted=316.589, expected=303.000
# >predicted=296.200, expected=303.000
# >predicted=298.361, expected=299.000
# >predicted=294.993, expected=295.000
# >predicted=291.424, expected=289.000
# >predicted=285.297, expected=289.000
# >predicted=286.474, expected=294.000
# >predicted=293.330, expected=294.000
# >predicted=293.543, expected=306.000
# >predicted=308.216, expected=317.000
# >predicted=320.830, expected=323.000
# >predicted=326.876, expected=320.000
# >predicted=322.009, expected=297.000
# >predicted=293.525, expected=281.000
# >predicted=275.254, expected=281.000
# >predicted=277.087, expected=285.000
# >predicted=283.177, expected=285.000
# >predicted=283.758, expected=305.000
# >predicted=308.370, expected=310.000
# >predicted=313.350, expected=310.000
# >predicted=312.282, expected=339.000
# >predicted=346.671, expected=350.000
# >predicted=357.546, expected=368.000
# >predicted=376.941, expected=389.000
# >predicted=399.526, expected=414.000
# >predicted=426.456, expected=423.000
# >predicted=433.378, expected=435.000
# >predicted=444.601, expected=454.000
# >predicted=464.557, expected=460.000
# >predicted=468.452, expected=467.000
# >predicted=474.232, expected=464.000
# >predicted=468.281, expected=464.000
# >predicted=466.909, expected=486.000
# >predicted=492.638, expected=497.000
# >predicted=503.845, expected=512.000
# >predicted=519.833, expected=517.000
# >predicted=523.390, expected=510.000
# >predicted=512.868, expected=510.000
# >predicted=511.951, expected=529.000
# >predicted=534.346, expected=528.000
# >predicted=531.430, expected=540.000
# >predicted=544.871, expected=558.000
# >predicted=565.120, expected=558.000
# >predicted=562.851, expected=575.000
# >predicted=581.895, expected=575.000
# >predicted=579.699, expected=571.000
# >predicted=573.356, expected=576.000
# >predicted=578.661, expected=570.000
# >predicted=570.546, expected=571.000
# >predicted=571.583, expected=575.000
# >predicted=576.242, expected=584.000
# >predicted=586.745, expected=592.000
# >predicted=595.559, expected=599.000
# >predicted=602.903, expected=599.000
# >predicted=601.659, expected=599.000
# >predicted=600.812, expected=619.000
# >predicted=624.455, expected=619.000
# >predicted=622.718, expected=615.000
# >predicted=616.691, expected=617.000
# >predicted=618.574, expected=629.000
# >predicted=632.604, expected=618.000
# >predicted=618.138, expected=613.000
# >predicted=612.040, expected=613.000
# >predicted=612.345, expected=597.000
# >predicted=593.179, expected=577.000
# >predicted=570.170, expected=572.000
# >predicted=566.293, expected=566.000
# >predicted=560.845, expected=543.000
# >predicted=534.629, expected=526.000
# >predicted=516.704, expected=508.000
# >predicted=497.861, expected=500.000
# >predicted=491.405, expected=500.000
# >predicted=494.150, expected=495.000
# >predicted=489.960, expected=490.000
# >predicted=485.511, expected=482.000
# >predicted=477.251, expected=472.000
# >predicted=466.651, expected=472.000
# >predicted=468.358, expected=461.000
# >predicted=456.194, expected=463.000
# >predicted=460.150, expected=460.000
# >predicted=457.425, expected=465.000
# >predicted=464.304, expected=481.000
# >predicted=483.914, expected=490.000
# >predicted=493.890, expected=478.000
# >predicted=478.107, expected=437.000
# >predicted=428.402, expected=408.000
# >predicted=395.985, expected=381.000
# >predicted=367.086, expected=372.000
# >predicted=360.645, expected=366.000
# >predicted=357.018, expected=359.000
# >predicted=351.416, expected=350.000
# >predicted=342.938, expected=345.000
# >predicted=339.144, expected=335.000
# >predicted=328.898, expected=323.000
# >predicted=316.305, expected=313.000
# >predicted=306.328, expected=313.000
# >predicted=308.471, expected=310.000
# >predicted=306.288, expected=305.000
# >predicted=301.417, expected=305.000
# >predicted=302.568, expected=295.000
# >predicted=291.223, expected=293.000
# >predicted=290.010, expected=292.000
# >predicted=289.757, expected=299.000
# >predicted=298.965, expected=306.000
# >predicted=307.465, expected=320.000
# >predicted=323.974, expected=331.000
# >predicted=336.039, expected=335.000
# >predicted=339.269, expected=321.000
# >predicted=320.917, expected=309.000
# >predicted=306.389, expected=303.000
# >predicted=299.951, expected=299.000
# >predicted=296.081, expected=296.000
# >predicted=293.382, expected=296.000
# >predicted=294.225, expected=299.000
# >predicted=298.435, expected=296.000
# >predicted=294.978, expected=314.000
# >predicted=317.140, expected=329.000
# >predicted=334.327, expected=336.000
# >predicted=341.101, expected=351.000
# >predicted=357.656, expected=351.000
# >predicted=355.508, expected=376.000
# >predicted=384.385, expected=376.000
# >predicted=381.681, expected=400.000
# >predicted=408.967, expected=407.000
# >predicted=414.570, expected=411.000
# >predicted=416.984, expected=417.000
# >predicted=422.335, expected=432.000
# >predicted=438.814, expected=435.000
# >predicted=440.259, expected=435.000
# >predicted=438.565, expected=457.000
# >predicted=464.104, expected=465.000
# >predicted=471.523, expected=466.000
# >predicted=470.638, expected=457.000
# >predicted=458.227, expected=464.000
# >predicted=466.324, expected=465.000
# >predicted=466.789, expected=475.000
# >predicted=478.342, expected=482.000
# >predicted=485.757, expected=493.000
# >predicted=497.890, expected=508.000
# >predicted=514.510, expected=522.000
# >predicted=529.398, expected=532.000
# >predicted=539.149, expected=532.000
# >predicted=536.849, expected=567.000
# >predicted=577.742, expected=576.000
# >predicted=585.208, expected=580.000
# >predicted=587.102, expected=583.000
# >predicted=588.459, expected=576.000
# >predicted=578.212, expected=581.000
# >predicted=583.566, expected=584.000
# >predicted=586.380, expected=583.000
# >predicted=584.402, expected=590.000
# >predicted=592.441, expected=581.000
# >predicted=580.742, expected=588.000
# >predicted=589.314, expected=596.000
# >predicted=598.593, expected=620.000
# >predicted=626.865, expected=628.000
# >predicted=634.362, expected=614.000
# >predicted=615.343, expected=614.000
# >predicted=614.911, expected=591.000
# >predicted=586.722, expected=591.000
# >predicted=588.099, expected=591.000
# >predicted=589.032, expected=561.000
# >predicted=553.282, expected=549.000
# >predicted=541.208, expected=543.000
# >predicted=536.438, expected=528.000
# >predicted=520.354, expected=509.000
# >predicted=499.766, expected=509.000
# >predicted=502.737, expected=503.000
# >predicted=497.474, expected=494.000
# >predicted=488.334, expected=482.000
# >predicted=475.601, expected=470.000
# >predicted=463.102, expected=461.000
# >predicted=454.403, expected=463.000
# >predicted=458.950, expected=467.000
# >predicted=465.106, expected=479.000
# >predicted=480.278, expected=484.000
# >predicted=485.934, expected=493.000
# >predicted=496.232, expected=494.000
# >predicted=496.402, expected=472.000
# >predicted=468.940, expected=457.000
# >predicted=451.726, expected=425.000
# >predicted=414.584, expected=425.000
# >predicted=417.954, expected=387.000
# >predicted=374.106, expected=377.000
# >predicted=366.133, expected=377.000
# >predicted=369.644, expected=367.000
# >predicted=359.882, expected=360.000
# >predicted=353.685, expected=353.000
# >predicted=347.228, expected=337.000
# >predicted=329.672, expected=330.000
# >predicted=323.541, expected=319.000
# >predicted=312.275, expected=307.000
# >predicted=299.881, expected=301.000
# >predicted=294.895, expected=294.000
# >predicted=288.368, expected=287.000
# >predicted=281.689, expected=280.000
# >predicted=274.907, expected=276.000
# >predicted=271.694, expected=276.000
# >predicted=273.083, expected=282.000
# >predicted=281.306, expected=292.000
# >predicted=293.669, expected=297.000
# >predicted=299.199, expected=311.000
# >predicted=315.484, expected=317.000
# >predicted=321.318, expected=307.000
# >predicted=307.784, expected=299.000
# >predicted=297.821, expected=290.000
# >predicted=287.277, expected=282.000
# >predicted=278.446, expected=285.000
# >predicted=283.237, expected=294.000
# >predicted=294.731, expected=294.000
# >predicted=294.495, expected=303.000
# >predicted=305.260, expected=310.000
# >predicted=313.026, expected=309.000
# >predicted=310.833, expected=324.000
# >predicted=328.449, expected=343.000
# >predicted=350.077, expected=342.000
# >predicted=346.572, expected=358.000
# >predicted=364.516, expected=366.000
# >predicted=372.121, expected=368.000
# >predicted=372.568, expected=368.000
# >predicted=371.090, expected=395.000
# >predicted=402.866, expected=410.000
# >predicted=418.534, expected=411.000
# >predicted=416.990, expected=410.000
# >predicted=413.839, expected=409.000
# >predicted=411.383, expected=407.000
# >predicted=408.184, expected=406.000
# >predicted=406.586, expected=406.000
# >predicted=406.397, expected=406.000
# >predicted=406.268, expected=418.000
# >predicted=420.748, expected=430.000
# >predicted=434.426, expected=419.000
# >predicted=419.643, expected=425.000
# >predicted=426.718, expected=425.000
# >predicted=426.163, expected=446.000
# >predicted=451.274, expected=446.000
# >predicted=449.571, expected=467.000
# >predicted=473.904, expected=467.000
# >predicted=471.675, expected=500.000
# >predicted=510.216, expected=515.000
# >predicted=525.126, expected=525.000
# >predicted=533.996, expected=533.000
# >predicted=540.802, expected=544.000
# >predicted=551.636, expected=536.000
# >predicted=539.457, expected=536.000
# >predicted=538.339, expected=549.000
# >predicted=553.364, expected=547.000
# >predicted=549.528, expected=538.000
# >predicted=537.787, expected=530.000
# >predicted=528.143, expected=546.000
# >predicted=548.163, expected=545.000
# >predicted=546.252, expected=543.000
# >predicted=543.421, expected=550.000
# >predicted=551.779, expected=553.000
# >predicted=554.846, expected=555.000
# >predicted=556.677, expected=551.000
# >predicted=551.282, expected=548.000
# >predicted=547.551, expected=551.000
# >predicted=551.336, expected=539.000
# ...
# >predicted=356.430, expected=350.000
# >predicted=337.419, expected=343.000
# >predicted=332.968, expected=342.000
# >predicted=334.974, expected=332.000
# >predicted=325.103, expected=326.000
# >predicted=320.040, expected=309.000
# >predicted=301.340, expected=297.000
# >predicted=289.246, expected=286.000
# >predicted=278.394, expected=281.000
# >predicted=274.769, expected=275.000
# >predicted=269.491, expected=271.000
# >predicted=266.407, expected=272.000
# >predicted=269.092, expected=272.000
# >predicted=270.024, expected=272.000
# >predicted=270.658, expected=257.000
# >predicted=252.904, expected=264.000
# >predicted=262.700, expected=264.000
# >predicted=263.117, expected=282.000
# >predicted=285.221, expected=281.000
# >predicted=282.975, expected=281.000
# >predicted=282.342, expected=258.000
# >predicted=254.036, expected=253.000
# >predicted=249.245, expected=253.000
# >predicted=250.448, expected=253.000
# >predicted=251.265, expected=268.000
# >predicted=270.001, expected=268.000
# >predicted=269.360, expected=269.000
# >predicted=270.136, expected=270.000
# >predicted=270.984, expected=270.000
# >predicted=270.669, expected=270.000
# >predicted=270.455, expected=288.000
# >predicted=292.125, expected=297.000
# >predicted=301.713, expected=307.000
# >predicted=312.324, expected=331.000
# >predicted=339.714, expected=351.000
# >predicted=361.171, expected=351.000
# >predicted=357.907, expected=401.000
# >predicted=416.317, expected=424.000
# >predicted=439.305, expected=433.000
# >predicted=445.311, expected=415.000
# >predicted=419.527, expected=385.000
# >predicted=381.627, expected=382.000
# >predicted=379.077, expected=385.000
# >predicted=383.664, expected=379.000
# >predicted=376.816, expected=388.000
# >predicted=388.438, expected=388.000
# >predicted=388.297, expected=388.000
# >predicted=388.201, expected=386.000
# >predicted=385.710, expected=397.000
# >predicted=399.146, expected=407.000
# >predicted=410.585, expected=435.000
# >predicted=443.400, expected=443.000
# >predicted=450.394, expected=430.000
# >predicted=432.236, expected=429.000
# >predicted=430.301, expected=429.000
# >predicted=429.881, expected=452.000
# >predicted=457.495, expected=473.000
# >predicted=481.198, expected=474.000
# >predicted=479.767, expected=486.000
# >predicted=492.464, expected=486.000
# >predicted=490.380, expected=498.000
# >predicted=503.524, expected=505.000
# >predicted=510.234, expected=504.000
# >predicted=507.334, expected=504.000
# >predicted=506.259, expected=500.000
# >predicted=500.678, expected=506.000
# >predicted=507.738, expected=514.000
# >predicted=516.881, expected=540.000
# >predicted=547.488, expected=534.000
# >predicted=537.798, expected=544.000
# >predicted=548.703, expected=534.000
# >predicted=535.062, expected=498.000
# >predicted=491.042, expected=493.000
# >predicted=487.225, expected=483.000
# >predicted=476.957, expected=482.000
# >predicted=477.696, expected=479.000
# >predicted=475.446, expected=470.000
# >predicted=465.676, expected=449.000
# >predicted=441.597, expected=449.000
# >predicted=443.986, expected=449.000
# >predicted=445.604, expected=440.000
# >predicted=435.783, expected=447.000
# >predicted=445.635, expected=436.000
# >predicted=432.732, expected=431.000
# >predicted=427.722, expected=431.000
# >predicted=428.779, expected=417.000
# >predicted=412.515, expected=413.000
# >predicted=409.110, expected=413.000
# >predicted=410.364, expected=413.000
# >predicted=411.213, expected=422.000
# >predicted=422.706, expected=407.000
# >predicted=404.286, expected=407.000
# >predicted=405.160, expected=407.000
# >predicted=405.753, expected=378.000
# >predicted=370.990, expected=360.000
# >predicted=351.416, expected=346.000
# >predicted=337.201, expected=335.000
# >predicted=326.694, expected=326.000
# >predicted=318.455, expected=329.000
# >predicted=324.528, expected=328.000
# >predicted=324.758, expected=310.000
# >predicted=303.969, expected=307.000
# >predicted=302.274, expected=300.000
# >predicted=295.307, expected=299.000
# >predicted=295.606, expected=299.000
# >predicted=296.700, expected=289.000
# >predicted=285.313, expected=288.000
# >predicted=285.288, expected=288.000
# >predicted=286.161, expected=272.000
# >predicted=267.350, expected=271.000
# >predicted=267.634, expected=272.000
# >predicted=269.930, expected=278.000
# >predicted=277.873, expected=295.000
# >predicted=298.534, expected=310.000
# >predicted=315.593, expected=311.000
# >predicted=315.000, expected=294.000
# >predicted=293.092, expected=290.000
# >predicted=288.533, expected=277.000
# >predicted=273.237, expected=274.000
# >predicted=270.813, expected=279.000
# >predicted=277.906, expected=270.000
# >predicted=267.343, expected=272.000
# >predicted=270.626, expected=278.000
# >predicted=278.346, expected=278.000
# >predicted=278.234, expected=301.000
# >predicted=306.057, expected=303.000
# >predicted=306.850, expected=303.000
# >predicted=305.607, expected=311.000
# >predicted=314.469, expected=311.000
# >predicted=313.350, expected=331.000
# >predicted=336.849, expected=350.000
# >predicted=358.010, expected=350.000
# >predicted=355.424, expected=373.000
# >predicted=381.573, expected=388.000
# >predicted=397.004, expected=407.000
# >predicted=417.150, expected=433.000
# >predicted=445.423, expected=440.000
# >predicted=449.907, expected=441.000
# >predicted=447.921, expected=439.000
# >predicted=443.256, expected=439.000
# >predicted=441.879, expected=449.000
# >predicted=453.084, expected=459.000
# >predicted=463.898, expected=477.000
# >predicted=484.155, expected=490.000
# >predicted=497.618, expected=499.000
# >predicted=506.080, expected=531.000
# >predicted=542.622, expected=560.000
# >predicted=574.070, expected=565.000
# >predicted=575.595, expected=553.000
# >predicted=557.608, expected=560.000
# >predicted=564.616, expected=569.000
# >predicted=574.047, expected=574.000
# >predicted=578.485, expected=584.000
# >predicted=589.172, expected=588.000
# >predicted=592.357, expected=569.000
# >predicted=567.896, expected=578.000
# >predicted=579.174, expected=581.000
# >predicted=582.435, expected=576.000
# >predicted=575.907, expected=587.000
# >predicted=589.280, expected=602.000
# >predicted=606.739, expected=613.000
# >predicted=618.556, expected=611.000
# >predicted=614.339, expected=613.000
# >predicted=615.689, expected=613.000
# >predicted=614.822, expected=590.000
# >predicted=586.332, expected=575.000
# >predicted=569.311, expected=571.000
# >predicted=566.296, expected=550.000
# >predicted=542.332, expected=537.000
# >predicted=529.034, expected=535.000
# >predicted=529.184, expected=527.000
# >predicted=521.356, expected=520.000
# >predicted=514.686, expected=520.000
# >predicted=516.405, expected=502.000
# >predicted=495.723, expected=488.000
# >predicted=480.762, expected=485.000
# >predicted=479.460, expected=480.000
# >predicted=475.183, expected=472.000
# >predicted=467.031, expected=463.000
# >predicted=457.715, expected=463.000
# >predicted=459.422, expected=452.000
# >predicted=447.230, expected=448.000
# >predicted=443.916, expected=449.000
# >predicted=446.449, expected=458.000
# >predicted=458.196, expected=458.000
# >predicted=458.132, expected=451.000
# >predicted=449.595, expected=467.000
# >predicted=469.464, expected=465.000
# >predicted=466.240, expected=449.000
# >predicted=446.428, expected=419.000
# >predicted=410.852, expected=399.000
# >predicted=389.206, expected=385.000
# >predicted=375.381, expected=368.000
# >predicted=357.857, expected=368.000
# >predicted=361.145, expected=350.000
# >predicted=341.512, expected=340.000
# >predicted=332.120, expected=333.000
# >predicted=326.174, expected=323.000
# >predicted=316.243, expected=313.000
# >predicted=306.290, expected=307.000
# >predicted=301.178, expected=305.000
# >predicted=300.635, expected=297.000
# >predicted=292.336, expected=293.000
# >predicted=288.990, expected=285.000
# >predicted=280.576, expected=282.000
# >predicted=278.366, expected=283.000
# >predicted=280.756, expected=286.000
# >predicted=285.124, expected=295.000
# >predicted=296.335, expected=303.000
# >predicted=305.616, expected=303.000
# >predicted=304.768, expected=317.000
# >predicted=321.193, expected=317.000
# >predicted=319.834, expected=296.000
# >predicted=293.422, expected=292.000
# >predicted=289.401, expected=292.000
# >predicted=290.243, expected=283.000
# >predicted=279.886, expected=290.000
# >predicted=289.393, expected=290.000
# >predicted=289.590, expected=302.000
# >predicted=304.290, expected=314.000
# >predicted=318.118, expected=329.000
# >predicted=334.997, expected=342.000
# >predicted=348.838, expected=342.000
# >predicted=346.618, expected=368.000
# >predicted=376.692, expected=372.000
# >predicted=378.729, expected=376.000
# >predicted=381.403, expected=385.000
# >predicted=390.579, expected=394.000
# >predicted=399.698, expected=393.000
# >predicted=396.635, expected=393.000
# >predicted=395.455, expected=409.000
# >predicted=414.087, expected=430.000
# >predicted=437.936, expected=419.000
# >predicted=422.010, expected=419.000
# >predicted=421.035, expected=420.000
# >predicted=421.589, expected=424.000
# >predicted=425.931, expected=438.000
# >predicted=442.300, expected=438.000
# >predicted=440.908, expected=438.000
# >predicted=439.967, expected=454.000
# >predicted=458.752, expected=467.000
# >predicted=472.994, expected=488.000
# >predicted=496.549, expected=510.000
# >predicted=520.494, expected=513.000
# >predicted=520.736, expected=513.000
# >predicted=518.229, expected=528.000
# >predicted=534.749, expected=551.000
# >predicted=560.489, expected=563.000
# >predicted=571.988, expected=563.000
# >predicted=569.079, expected=539.000
# >predicted=537.959, expected=539.000
# >predicted=538.297, expected=539.000
# >predicted=538.526, expected=551.000
# >predicted=553.249, expected=551.000
# >predicted=552.520, expected=575.000
# >predicted=581.163, expected=571.000
# >predicted=574.312, expected=561.000
# >predicted=561.102, expected=562.000
# >predicted=562.283, expected=556.000
# >predicted=554.908, expected=568.000
# >predicted=569.827, expected=568.000
# >predicted=569.236, expected=550.000
# >predicted=546.990, expected=547.000
# >predicted=544.323, expected=541.000
# >predicted=537.906, expected=532.000
# >predicted=527.983, expected=518.000
# >predicted=512.289, expected=495.000
# >predicted=486.215, expected=473.000
# >predicted=462.345, expected=458.000
# >predicted=447.584, expected=449.000
# >predicted=440.033, expected=439.000
# >predicted=430.797, expected=450.000
# >predicted=446.822, expected=446.000
# >predicted=442.996, expected=433.000
# >predicted=428.182, expected=433.000
# >predicted=429.745, expected=412.000
# >predicted=405.301, expected=412.000
# >predicted=407.472, expected=408.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bc0a7bab8c3e> in <module>
#      27 for t in range(len(test)):
#      28     model = sm.tsa.statespace.SARIMAX(history, order=(1,1,1))
# ---> 29     model_fit = model.fit(trend='nc', disp=False)
#      30     ar_coef, ma_coef = model_fit.arparams, model_fit.maparams
#      31     resid = model_fit.resid
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     481                                            full_output=full_output,
#     482                                            disp=disp, callback=callback,
# --> 483                                            skip_hessian=True, **kwargs)
#     484
#     485         # Just return the fitted parameters if requested
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     658             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     659
# --> 660         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     661
#     662         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     873                                ' MEMORY_NO_LIKELIHOOD option is selected.')
#     874         kwargs['conserve_memory'] = MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD
# --> 875         kfilter = self._filter(**kwargs)
#     876         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     877                                         self.loglikelihood_burn)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     800
#     801         # Run the filter
# --> 802         kfilter()
#     803
#     804         return kfilter
#
# KeyboardInterrupt:

# %% [markdown]
# ### Calcolo dell'errore

# %%
error = abs(np.array(predictions) - np.array(expected))
print('MSE ', error.mean())

plt.figure(figsize=(16, 2))
plt.boxplot(error, vert = False);
plt.show()
# Out:
# MSE  7.76805242098328

# %%
cell = '488-1264'
dict2data = {}
minimum = np.amin(error)   
per75 = np.percentile(error, 75)
per50 = np.percentile(error, 50)
per25 = np.percentile(error, 25)
maximum = np.amax(error)
l5i = [minimum, per25, per50, per75, maximum]
dict2data[cell] = l5i

with open('error_data_4_cell_488-1264_SARIMA_param_1.1.1.csv', 'w') as f:
    for key, value in dict2data.items():
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# ### Calcolo errore di previsone per ogni cella con SARIMA

# %%
def predict(coef, history):
    yhat = 0.0
    for i in range(1, len(coef)+1):
        yhat += coef[i-1] * history[-i]
    return yhat
 
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return numpy.array(diff)

count = 0
dict2data = {}
for i, k in gbc: 
    cell = i
    count += 1
    if count > 2: break
    X = k['nr_people'].values
    X = X[0:1000]
    size = len(X) - 400
    train, test = X[0:size], X[size:]
    history = [x for x in train]
    predictions = list()
    expected = list()
    for t in range(len(test)):
        model = sm.tsa.statespace.SARIMAX(history, order=(1,1,1))
        model_fit = model.fit(trend='nc', disp=False)
        ar_coef, ma_coef = model_fit.arparams, model_fit.maparams
        resid = model_fit.resid
        diff = difference(history)
        yhat = history[-1] + predict(ar_coef, diff) + predict(ma_coef, resid)
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
        expected.append(obs)
        #print('>predicted=%.3f, expected=%.3f' % (yhat, obs))
    rmse = sqrt(mean_squared_error(test, predictions))
    print('Test RMSE: %.3f' % rmse)   
    
    error = abs(test - predictions)
    
    minimum = np.amin(error)   
    per75 = np.percentile(error, 75)
    per50 = np.percentile(error, 50)
    per25 = np.percentile(error, 25)
    maximum = np.amax(error)
    
    l5i = [minimum, per25, per50, per75, maximum]
    list_i = ", ".join(l5i)
    dict2data[cell] = list_i

with open('error_data_4_cell_488-1264_SARIMA_param_1.1.1.csv', 'w') as f:
    for key, value in dict2data.items():
        f.write('%s:%s\n' % (key, value))
# Out:
# Test RMSE: 1.232
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3336982a9c6c> in <module>
#      49
#      50     l5i = [minimum, per25, per50, per75, maximum]
# ---> 51     list_i = ", ".join(l5i)
#      52     dict2data[cell] = list_i
#      53
#
# TypeError: sequence item 0: expected str instance, numpy.float64 found
